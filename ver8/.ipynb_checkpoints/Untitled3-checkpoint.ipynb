# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Dec 27 13:33:05 2022

@author: parkh
"""
    
import pandas as pd
import numpy as np
from datetime import datetime
import plotly.express as px
import copy
import random
from matplotlib import pylab as plt
from Resource3 import *
from Job3 import *
from collections import defaultdict
    
    
class FJSP_simulator():
        
    def __init__(self, data, setup_data,number_of_job, k):
        self.k = k
        self.done = False
        self.event_list=[]
        self.process_time_table = pd.read_csv(data,index_col=(0))
        self.setup_time_table = pd.read_csv(setup_data, index_col=(0))
        self.number_of_job = pd.read_csv(number_of_job, index_col=(0))
        self.machine_number = len(self.process_time_table.columns)
        """총 job 개수"""
        operation = self.process_time_table.index
        op_table=[]
        for i in range(len(operation)):
            op_table.append(operation[i][1:3])
        self.job_number = len(set(op_table))
        """각 job type 별로 총 job 개수"""
        self.total_job = [0 for x in range(self.job_number)]
        self.remain_job = copy.deepcopy(self.total_job)
        for i in range(self.job_number):
            self.total_job[i] = self.number_of_job["number"].loc[i+1]
        self.remain_job = copy.deepcopy(self.total_job)    
        
        """각 job별로 총 operation개수"""
        self.max_operation = [0 for x in range(self.job_number)]
        self.total_operation = [0 for x in range(self.job_number)]
        for i in range(1, self.job_number+1):
            for j in op_table:
                if i == int(j):
                    self.max_operation[i-1] +=1
        for i,a in enumerate(self.max_operation):
            self.total_operation[i] =  a * self.total_job[i]  
        self.num_of_op = sum(self.total_operation)
        """job 인스턴스 생성"""
        self.j_list = defaultdict(Job)
        for i in range(self.job_number):
            for k in range(self.total_job[i]):
                job_id = "j"+str(i)+ str(k)
                j = Job(job_id,i+1,self.max_operation[i],self.setup_time_table) 
                self.j_list[j.id] = j
        """machine 인스턴스 생성"""
        s = []
        self.r_list = defaultdict(Resource)
        for i in range(self.machine_number):
            r = Resource("M"+str(i+1))
            self.r_list[r.id] = r
        self.time = 0 #시간
        self.end = True #종료조건
        self.j=0
        self.plotlydf = pd.DataFrame([],columns=['Type','JOB_ID','Task','Start','Finish','Resource','Rule','Step'])
        self.step_number = 1
    def reset(self):
        self.done = False
        self.event_list=[]
        """총 job 개수"""
        operation = self.process_time_table.index
        op_table=[]
        for i in range(len(operation)):
            op_table.append(operation[i][1:3])
        self.job_number = len(set(op_table))
        """각 job type 별로 총 job 개수"""
        self.total_job = [0 for x in range(self.job_number)]
        for i in range(self.job_number):
            self.total_job[i] = self.number_of_job["number"].loc[i+1]
            
        self.remain_job = copy.deepcopy(self.total_job)
        """각 job별로 총 operation개수"""
        self.max_operation = [0 for x in range(self.job_number)]
        self.total_operation = [0 for x in range(self.job_number)]
        for i in range(1, self.job_number+1):
            for j in op_table:
                if i == int(j):
                    self.max_operation[i-1] +=1
        for i,a in enumerate(self.max_operation):
            self.total_operation[i] =  a * self.total_job[i]  
        self.num_of_op = sum(self.total_operation)
        """job 인스턴스 생성"""
        self.j_list = defaultdict(Job)
        for i in range(self.job_number):
            for k in range(self.total_job[i]):
                job_id = "j"+str(i)+ str(k)
                j = Job(job_id,i+1,self.max_operation[i],self.setup_time_table) 
                self.j_list[j.id] = j
        """machine 인스턴스 생성"""
        self.r_list = defaultdict(Resource)
        for i in range(self.machine_number):
            r = Resource("M"+str(i+1))
            self.r_list[r.id] = r
        self.time = 0 #시간
        self.end = True #종료조건
        self.j = 0
        self.plotlydf = pd.DataFrame([],columns=["Type",'JOB_ID','Task','Start','Finish','Resource','Rule','Step'])
        s = []
        #remain operation ,last work finish time
        for i in range(self.job_number):
            s.append(self.total_job[i]) #remain_job
            s.append(self.total_operation[i]) #remain_operation
        for machine in self.r_list:
            s.append(self.r_list[machine].reservation_time) # 예약시간
            s.append(self.r_list[machine].setup_status) #셋업상태
            s.append(self.r_list[machine].job_id_processed) #진행중인 작업 type
        df = pd.Series(s)
        s = df.to_numpy()
        self.step_number = 1
        return s
    def performance_measure(self):
        Flow_time = 0
        value_time_table = []
        full_time_table = []
        machine_util = 0
        util = 0
        makespan = self.time
        for machine in self.r_list:
            value_added_time, full_time = self.r_list[machine].util()
            value_time_table.append(value_added_time)
            full_time_table.append(full_time)
        util = sum(value_time_table)/sum(full_time_table)
        for job in self.j_list:
            Flow_time += self.j_list[job].job_flowtime
        #fig = px.timeline(self.plotlydf, x_start="Start", x_end="Finish", y="Resource", color="Task", width=1000, height=400)
        #fig.show()
        return Flow_time, machine_util, util, makespan
    def modify_width(self, bar, width):
        """
        막대의 너비를 설정합니다.
        width = (단위 px)
        """
        bar.width = width
    def modify_text(self, bar):
        """
        막대의 텍스트를 설정합니다.
        width = (단위 px)
        """
        bar.text = ""
    def to_bottom_setup_df(self, df):
        """
        figure의 경우 위에서 부터 bar 생성됩니다.
        track_in event를 df(데이터프레임) 가장 밑 행으로 배치시킵니다.
        이 작업을 통해 TRACK_IN 이벤트가 다른 중복되는 차트에 가려지는 것을 방지합니다.
        """
        setup_df = df.loc[df['Type'] == 'setup']
        df = df[df['Type'] != 'setup']
        df = df.append(setup_df, ignore_index=True)
        return df
    
    def gannt_chart(self):
        step_rule = []
        for i in range(len(self.plotlydf)):
            if str(self.plotlydf["Rule"].loc[i])  != "None":
                step_rule.append(str(self.plotlydf["Step"].loc[i])+"-"+str(self.plotlydf["Rule"].loc[i]))
            else:
                step_rule.append("NONE")
        self.plotlydf["Step-Rule"] = step_rule
        
        id_op = []
        for i in range(len(self.plotlydf)):
            if str(self.plotlydf["Task"].loc[i])  != "None":
                id_op.append(str(self.plotlydf["JOB_ID"].loc[i])+"-"+str(self.plotlydf["Task"].loc[i]))
            else:
                id_op.append("NONE")
        self.plotlydf["ID_OP"] = id_op
        
        plotlydf2 = self.plotlydf.sort_values(by=['Resource','Type'], ascending=False)
        df = self.to_bottom_setup_df(plotlydf2) #setup 뒤로 보낸 데이터 프레임
        
        fig = px.timeline(df, x_start="Start", x_end="Finish", y="Resource", hover_data=['Rule'],template="simple_white",color="Type", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "Task", width=2000, height=800)
        fig.update_traces(marker=dict(line_color="black"))
        
        [(self.modify_width(bar, 0.7))
        for bar in fig.data if ('setup' in bar.legendgroup)]
        #fig.show()
        
        #fig,write_html(f"{PathInfo.xlsx}{os.sep}temp_target.html", default_width=2300, default_height=900)
        plotlydf3 = self.plotlydf.sort_values(by=['Type'], ascending=True)
        fig2 = px.timeline(plotlydf3, x_start="Start", x_end="Finish", y="Type", template="seaborn" ,color="Resource",text = "Resource", width=2000, height=1000)
        fig2.update_traces(marker=dict(line_color="yellow", cmid = 1000))
        #fig2.show()
        
        fig3 = px.timeline(df, x_start="Start", x_end="Finish", y="Resource", template="simple_white",color="Type", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "Rule", width=2000, height=800)
        [(self.modify_width(bar, 0.7), self.modify_text(bar)) for bar in fig3.data if ('setup' in bar.legendgroup)]
        #fig3.show()
        
        
        fig4 = px.timeline(df, x_start="Start", x_end="Finish", y="Resource", template="simple_white",color="Type", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "Step-Rule", width=2000, height=800)
        [(self.modify_width(bar, 0.7), self.modify_text(bar))
        for bar in fig4.data if ('setup' in bar.legendgroup)]
        #fig4.show()
        
        fig5 = px.timeline(df, x_start="Start", x_end="Finish", y="Rule", template="simple_white",color="Rule", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "Step-Rule", width=2000, height=800)
        #fig5.show()
        
        fig6 = px.timeline(df, x_start="Start", x_end="Finish", y="Resource", template="simple_white",color="Type", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "ID_OP", width=2000, height=800)
        [(self.modify_width(bar, 0.7), self.modify_text(bar))
        for bar in fig6.data if ('setup' in bar.legendgroup)]
        fig6.show()
    #오퍼레이션 길이 50,메이크스팬 100, Max op 5,Min op 5, Max-min
    #39025431
    
    def step(self, action):
        done = False
        while True:
            machine = self.check_availability()
            if machine == "NONE":
                self.process_event()
                if self.num_of_op == 0:
                    done = True
                    #p_time = self.dispatching_rule_decision(machine, action)
                    s_prime = self.set_state()
                    #reservation_time = self.r_list[machine].reservation_time
                    #last_work_finish_time = self.r_list[machine].last_work_finish_time
                    r =  0
                    break
            else:
                p_time = self.dispatching_rule_decision(machine, action)
                s_prime = self.set_state()
                reservation_time = self.r_list[machine].reservation_time
                last_work_finish_time = self.r_list[machine].last_work_finish_time
                max_reservation = 0
                min_reservation = 100000000
                for machine in self.r_list:
                    if self.r_list[machine].reservation_time > max_reservation:
                        max_reservation = self.r_list[machine].reservation_time
                    if self.r_list[machine].reservation_time < min_reservation:
                        min_reservation = self.r_list[machine].reservation_time
                r = -(reservation_time-last_work_finish_time-p_time)
                break
        return s_prime, r , done
    
    def set_state(self):
        s=[]
        #machine = self.check_availability()
        #print(machine)
        #s.append(int(machine[1:]))
        for i in range(self.job_number):
            s.append(self.total_job[i]) #remain_job
            s.append(self.total_operation[i]) #remain_operation
        for machine in self.r_list:
            s.append(self.r_list[machine].reservation_time) # 예약시간
            s.append(self.r_list[machine].setup_status) #셋업상태
            s.append(self.r_list[machine].job_id_processed) #진행중인 작업 type
        df = pd.Series(s)
        s = df.to_numpy()
        return s
    def run(self):
        while True:
            machine = self.check_availability()
            if machine != "NONE":
                p_time = self.dispatching_rule_decision(machine, self.k)
            else:
                if len(self.event_list) == 0:
                    break
                self.process_event()
                
        
        Flow_time, machine_util, util, makespan = self.performance_measure()
        print(self.k)
        print("FlowTime:" , Flow_time)
        print("machine_util:" , machine_util)
        print("util:" , util)
        print("makespan:" , makespan)
        #self.gannt_chart()
        return Flow_time, util, makespan
    #event = (job_type, operation, machine_type, start_time, end_time, event_type)
    def dispatching_rule_decision(self,machine, a):
        #print(machine)
        if a == "random":
            coin = random.randint(0,9)
        else:
            coin = int(a)
        if coin == 0:
            p_time = self.dispatching_rule_SPT(machine)
        elif coin == 1:
            p_time = self.dispatching_rule_SPTSSU(machine)
        elif coin == 2:
            p_time = self.dispatching_rule_MOR(machine)
        elif coin == 3:
            p_time = self.dispatching_rule_MORSPT(machine)
        elif coin == 4:
            p_time = self.dispatching_rule_LOR(machine)
        elif coin == 5:
            p_time = self.dispatching_rule_LPT(machine)
        elif coin == 6:
            p_time = self.dispatching_rule_LJRLOR(machine)
        elif coin == 7:
            p_time = self.dispatching_rule_MJRMOR(machine)
        elif coin == 8:
            p_time = self.dispatching_rule_LWRLOR(machine)
        elif coin == 9:
            p_time = self.dispatching_rule_MWRMOR(machine)
        return p_time
    def process_event(self):
        self.event_list.sort(key = lambda x:x[4], reverse = False)
        event = self.event_list.pop(0)
        self.time = event[4]
        setup_time = event[8]
        job = event[0]
        machine = event[2]
        time = event[3]
        start = datetime.fromtimestamp(time*3600)
        time = event[4]
        end = datetime.fromtimestamp(time*3600)
        if event[5] == "setup_change":
            event_type = "setup"
        else:
            event_type = "j"+str(event[0].job_type)
            last = job.complete_setting(event[3]+setup_time, event[4],event[5]) # 작업이 대기로 변함, 시작시간, 종료시간, event_type
            machine.complete_setting(event[3]+setup_time,event[4],event[5]) # 기계도 사용가능하도록 변함
            if last == True:
                self.total_job[event[0].job_type-1] -= 1
            #self.dispatching_rule_decision("random")
            self.num_of_op -=1
        rule = event[6]
        step = event[7]
        operation = event[1]
        self.plotlydf.loc[self.j] = dict(Type = event_type,JOB_ID = event[0].id  ,Task=operation, Start=start, Finish=end, Resource=machine.id, Rule = rule, Step = step) #간트차트를 위한 딕셔너리 생성, 데이터프레임에 집어넣음
        self.j+=1
        if self.num_of_op == 0:
            done = True
        else:
            done = False
        return done
    
    def assign_setting(self, job, machine, reservation_time): #job = 1 machine = 1
        job.assign_setting(machine)
        self.total_operation[job.job_type-1] -=1
        machine.assign_setting(job, reservation_time)
        
    def complete_setting(self, job, machine):
        job.complete_setting()
        machine.complete_setting()
    def check_availability(self):
        index_k = 0
        select_machine = "NONE"
        for machine in self.r_list:
            index_k += 1
            if self.r_list[machine].status == 0:
                machine = self.r_list[machine].id #machine 이름
                p_table=[]
                for job in self.j_list: #job 이름과 operation이름 찾기
                    jop = self.j_list[job].jop()
                    if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                        pass
                    elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                        pass
                    elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                        pass
                    else: 
                        p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop]])
                if len(p_table) == 0:#현재 이벤트를 발생시킬 수 없음
                    pass
                else:
                    select_machine = machine
                    break
        return select_machine
                
    def dispatching_rule_SPT(self, machine):
        rule_name= "SPT"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        if len(p_table) == 0:#현재 이벤트를 발생시킬 수 없음
            pass
        else:
            p_table.sort(key = lambda x:x[1], reverse = False)
            setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
            jop = p_table[0][2]
            if setup_time !=0:
                self.event_list.append((p_table[0][0],"setup" , self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
            self.event_list.append((p_table[0][0], jop ,self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
            self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
    
    def dispatching_rule_LPT(self, machine):
        rule_name= "LPT"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:x[1], reverse = True)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop, self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish", rule_name, step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
        
    def dispatching_rule_SPTSSU(self, machine):
        rule_name= "SPTSSU"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            setup_time = self.j_list[job].setup_table['j'+str(self.r_list[machine].setup_status)]
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop]+setup_time, jop])
        p_table.sort(key = lambda x:x[1], reverse = False)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0], "setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop, self.r_list[machine], self.time, self.time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0],self.r_list[machine],self.time+p_table[0][1])
        return p_table[0][1] - setup_time
            
    def dispatching_rule_MOR(self,machine):
        rule_name= "MOR"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:x[0].remain_operation, reverse = True)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0],jop, self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
            
    def dispatching_rule_MORSPT(self, machine):
        rule_name= "MORSPT"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x : x[1]/x[0].remain_operation, reverse = False)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0], "setup",self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop,self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
        
            
    def dispatching_rule_LOR(self,machine):
        rule_name= "LOR"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:x[0].remain_operation, reverse = False)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop,self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
    
    def dispatching_rule_LJRLOR(self,machine):
        rule_name= "LJR"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:[self.total_job[x[0].job_type-1], x[0].remain_operation], reverse = False)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop,self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
    
    def dispatching_rule_MJRMOR(self,machine):
        rule_name= "MJR"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:[self.total_operation[x[0].job_type-1], x[0].remain_operation], reverse = True)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0],jop, self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
    
    def dispatching_rule_LWRLOR(self,machine):
        rule_name= "LWR"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:[self.total_operation[x[0].job_type-1], x[0].remain_operation], reverse = False)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop,self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
    
    def dispatching_rule_MWRMOR(self,machine):
        rule_name= "MWR"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:[self.total_job[x[0].job_type-1], x[0].remain_operation], reverse = True)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0],jop, self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
    
    
    
    
makespan_table = []
util = []
ft_table = []

for i in range(10):
    main = FJSP_simulator('C:/Users/parkh/git_tlsgudcks/simulator/data/FJSP_SIM7_all.csv','C:/Users/parkh/FJSP_SETUP_SIM.csv',"C:/Users/parkh/git_tlsgudcks/simulator/data/FJSP_Fab.csv",i)
    FT, util2, ms = main.run()
    makespan_table.append(ms)
    util.append(util2)
    ft_table.append(FT)
    main.gannt_chart()
print(makespan_table)
print(ft_table)
print(util)
# Out:
# 0
# FlowTime: 24710
# machine_util: 0
# util: 0.9053326810176126
# makespan: 738
# <div>                            <div id="f2b7c5e0-de79-4f97-a402-bfde4e17493c" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2b7c5e0-de79-4f97-a402-bfde4e17493c")) {                    Plotly.newPlot(                        "f2b7c5e0-de79-4f97-a402-bfde4e17493c",                        [{"alignmentgroup":"True","base":["1970-01-03T01:00:00","1970-01-03T14:00:00","1970-01-03T23:00:00","1970-01-06T14:00:00","1970-01-07T03:00:00","1970-01-07T11:00:00","1970-01-07T20:00:00","1970-01-08T03:00:00","1970-01-08T13:00:00","1970-01-08T21:00:00","1970-01-09T06:00:00","1970-01-10T01:00:00","1970-01-08T04:00:00","1970-01-08T17:00:00","1970-01-09T05:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j80-j0901","j81-j0901","j82-j0901","j80-j0902","j80-j0903","j80-j0904","j80-j0905","j81-j0902","j81-j0903","j81-j0904","j81-j0905","j82-j0905","j82-j0902","j82-j0903","j82-j0904"],"textposition":"auto","x":[46800000.0,32400000.0,32400000.0,46800000.0,28800000.0,32400000.0,25200000.0,36000000.0,28800000.0,32400000.0,25200000.0,36000000.0,46800000.0,43200000.0,43200000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M6","M6","M6","M6","M6","M6","M6","M2","M2","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-11T09:00:00","1970-01-12T00:00:00","1970-01-12T11:00:00","1970-01-12T22:00:00","1970-01-03T07:00:00","1970-01-03T14:00:00","1970-01-03T19:00:00","1970-01-04T00:00:00","1970-01-04T05:00:00","1970-01-04T10:00:00","1970-01-12T10:00:00","1970-01-12T23:00:00","1970-01-13T09:00:00","1970-01-13T19:00:00","1970-01-03T12:00:00","1970-01-02T21:00:00","1970-01-03T05:00:00","1970-01-03T11:00:00","1970-01-04T06:00:00","1970-01-04T19:00:00","1970-01-06T05:00:00","1970-01-06T19:00:00","1970-01-07T06:00:00","1970-01-07T17:00:00","1970-01-02T00:00:00","1970-01-02T10:00:00","1970-01-02T16:00:00","1970-01-02T22:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j60-j0706","j61-j0706","j62-j0706","j63-j0706","j60-j0703","j60-j0704","j61-j0703","j61-j0704","j62-j0703","j62-j0704","j60-j0707","j61-j0707","j62-j0707","j63-j0707","j63-j0702","j60-j0702","j61-j0702","j62-j0702","j63-j0703","j63-j0704","j60-j0705","j61-j0705","j62-j0705","j63-j0705","j60-j0701","j61-j0701","j62-j0701","j63-j0701"],"textposition":"auto","x":[54000000.0,39600000.0,39600000.0,39600000.0,25200000.0,18000000.0,18000000.0,18000000.0,18000000.0,18000000.0,46800000.0,36000000.0,36000000.0,36000000.0,36000000.0,28800000.0,21600000.0,21600000.0,46800000.0,32400000.0,50400000.0,39600000.0,39600000.0,39600000.0,36000000.0,21600000.0,21600000.0,21600000.0],"xaxis":"x","y":["M6","M6","M6","M6","M5","M5","M5","M5","M5","M5","M5","M5","M5","M5","M4","M3","M3","M3","M2","M2","M2","M2","M2","M2","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-04T08:00:00","1970-01-04T21:00:00","1970-01-05T07:00:00","1970-01-05T17:00:00","1970-01-05T13:00:00","1970-01-06T05:00:00","1970-01-06T17:00:00","1970-01-01T09:00:00","1970-01-02T00:00:00","1970-01-02T16:00:00","1970-01-03T01:00:00","1970-01-07T01:00:00"],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j6","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["j50-j0602","j51-j0602","j52-j0602","j53-j0602 ...
# 1
# FlowTime: 54856
# machine_util: 0
# util: 0.885376707073807
# makespan: 1096
# <div>                            <div id="93b34bbd-cab7-4aed-955c-83cff004c36e" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93b34bbd-cab7-4aed-955c-83cff004c36e")) {                    Plotly.newPlot(                        "93b34bbd-cab7-4aed-955c-83cff004c36e",                        [{"alignmentgroup":"True","base":["1970-01-13T10:00:00","1970-01-14T20:00:00","1970-01-16T07:00:00","1970-01-17T17:00:00","1970-01-19T04:00:00","1970-02-05T15:00:00","1970-02-06T14:00:00","1970-02-07T09:00:00","1970-02-05T14:00:00","1970-02-07T16:00:00","1970-02-04T08:00:00","1970-02-04T21:00:00","1970-02-06T04:00:00","1970-02-06T17:00:00","1970-02-08T09:00:00","1970-02-08T21:00:00","1970-02-09T15:00:00","1970-02-10T03:00:00","1970-02-10T18:00:00","1970-02-11T14:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j70-j0801","j71-j0801","j72-j0801","j73-j0801","j74-j0801","j70-j0804","j71-j0803","j71-j0804","j71-j0802","j72-j0804","j70-j0802","j70-j0803","j72-j0802","j72-j0803","j73-j0802","j73-j0803","j73-j0804","j74-j0802","j74-j0803","j74-j0804"],"textposition":"auto","x":[61200000.0,61200000.0,61200000.0,61200000.0,61200000.0,82800000.0,68400000.0,72000000.0,54000000.0,61200000.0,46800000.0,64800000.0,46800000.0,64800000.0,43200000.0,64800000.0,43200000.0,54000000.0,72000000.0,50400000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M4","M4","M4","M3","M3","M2","M2","M2","M2","M2","M2","M2","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-20T14:00:00","1970-01-21T11:00:00","1970-02-01T22:00:00","1970-02-03T00:00:00","1970-02-06T03:00:00","1970-01-20T07:00:00","1970-02-07T06:00:00","1970-01-16T10:00:00","1970-01-19T02:00:00","1970-01-20T18:00:00","1970-01-21T14:00:00","1970-01-22T09:00:00","1970-01-23T21:00:00","1970-01-31T22:00:00","1970-02-01T15:00:00","1970-02-04T22:00:00","1970-02-08T05:00:00","1970-01-18T12:00:00","1970-02-03T02:00:00","1970-02-04T01:00:00","1970-01-17T15:00:00","1970-01-22T13:00:00","1970-02-10T03:00:00","1970-02-10T14:00:00","1970-02-11T01:00:00","1970-02-11T17:00:00","1970-02-03T23:00:00","1970-02-04T20:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j61-j0702","j62-j0702","j60-j0705","j61-j0705","j62-j0705","j62-j0701","j62-j0706","j60-j0701","j61-j0701","j63-j0701","j61-j0703","j62-j0703","j63-j0703","j60-j0704","j61-j0704","j62-j0704","j62-j0707","j60-j0703","j60-j0706","j60-j0707","j60-j0702","j63-j0702","j63-j0704","j63-j0705","j63-j0706","j63-j0707","j61-j0706","j61-j0707"],"textposition":"auto","x":[75600000.0,64800000.0,93600000.0,82800000.0,93600000.0,57600000.0,68400000.0,68400000.0,75600000.0,72000000.0,68400000.0,68400000.0,82800000.0,61200000.0,50400000.0,61200000.0,68400000.0,64800000.0,82800000.0,57600000.0,64800000.0,64800000.0,39600000.0,39600000.0,57600000.0,72000000.0,75600000.0,61200000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M5","M5","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M3","M3","M3","M2","M2","M2","M2","M2","M2","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-02-05T13:00:00","1970-01-09T19:00:00","1970-02-04T11:00:00","1970-02-06T05:00:00","1970-01-21T20:00:00","1970-01-23T05:00:00","1970-01-27T00:00:00","1970-01-10T03:00:00","1970-01-11T15:00:00","1970-01-14T08:00:00","1970-01-16T20:00:00","1970-01-18T09:00:00","1970-01-19T21:00:00","1970-01-21T17:00:00","1970- ...
# 2
# FlowTime: 56345
# machine_util: 0
# util: 0.8400217904485201
# makespan: 923
# <div>                            <div id="0bd2fe5c-87df-4ace-8335-613a6a33b80b" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bd2fe5c-87df-4ace-8335-613a6a33b80b")) {                    Plotly.newPlot(                        "0bd2fe5c-87df-4ace-8335-613a6a33b80b",                        [{"alignmentgroup":"True","base":["1970-01-12T16:00:00","1970-01-27T11:00:00","1970-02-04T00:00:00","1970-01-07T03:00:00","1970-01-12T17:00:00","1970-01-07T03:00:00","1970-01-19T12:00:00","1970-01-27T00:00:00","1970-01-12T18:00:00","1970-01-19T20:00:00","1970-02-03T19:00:00","1970-01-07T06:00:00","1970-01-19T17:00:00","1970-01-27T12:00:00","1970-02-03T18:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j80-j0902","j81-j0904","j82-j0905","j80-j0901","j81-j0902","j81-j0901","j80-j0903","j80-j0904","j82-j0902","j82-j0903","j81-j0905","j82-j0901","j81-j0903","j82-j0904","j80-j0905"],"textposition":"auto","x":[43200000.0,43200000.0,36000000.0,43200000.0,68400000.0,82800000.0,46800000.0,64800000.0,57600000.0,54000000.0,61200000.0,36000000.0,54000000.0,54000000.0,64800000.0],"xaxis":"x","y":["M6","M6","M6","M5","M5","M4","M4","M4","M3","M3","M3","M2","M2","M2","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-26T21:00:00","1970-02-03T09:00:00","1970-01-12T08:00:00","1970-01-19T12:00:00","1970-01-26T20:00:00","1970-02-03T13:00:00","1970-01-12T12:00:00","1970-02-03T05:00:00","1970-01-12T10:00:00","1970-01-19T06:00:00","1970-01-26T23:00:00","1970-01-12T11:00:00","1970-01-19T05:00:00","1970-01-26T16:00:00","1970-02-03T04:00:00","1970-01-12T11:00:00","1970-01-18T22:00:00","1970-01-19T10:00:00","1970-01-26T16:00:00","1970-02-03T09:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j73-j0803","j73-j0804","j70-j0801","j74-j0802","j72-j0803","j74-j0804","j74-j0801","j71-j0804","j71-j0801","j72-j0802","j74-j0803","j72-j0801","j71-j0802","j70-j0803","j70-j0804","j73-j0801","j70-j0802","j73-j0802","j71-j0803","j72-j0804"],"textposition":"auto","x":[50400000.0,54000000.0,32400000.0,28800000.0,72000000.0,64800000.0,54000000.0,79200000.0,28800000.0,50400000.0,57600000.0,36000000.0,43200000.0,72000000.0,50400000.0,43200000.0,43200000.0,36000000.0,82800000.0,61200000.0],"xaxis":"x","y":["M6","M6","M5","M5","M5","M5","M4","M4","M3","M3","M3","M2","M2","M2","M2","M1","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T20:00:00","1970-01-03T01:00:00","1970-01-06T21:00:00","1970-01-12T06:00:00","1970-01-18T21:00:00","1970-01-26T07:00:00","1970-02-02T14:00:00","1970-01-01T19:00:00","1970-01-03T03:00:00","1970-01-18T15:00:00","1970-02-03T00:00:00","1970-01-11T21:00:00","1970-01-18T20:00:00","1970-01-26T06:00:00","1970-01-06T20:00:00","1970-01-11T22:00:00","1970-01-26T00:00:00","1970-02-03T00:00:00","1970-01-01T19:00:00","1970-01-03T08:00:00","1970-01-06T19:00:00","1970-01-18T15:00:00","1970-01-01T15:00:00","1970-01-03T01:00:00","1970-01-07T02:00:00","1970-01-12T02:00:00","1970-01-25T21:00:00","1970-02-02T13:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j63-j0701","j60-j0702","j62-j0703","j63-j0704","j63-j0705","j63-j0706","j61-j0707","j62-j0701 ...
# 3
# FlowTime: 37694
# machine_util: 0
# util: 0.8924897119341564
# makespan: 658
# <div>                            <div id="4e85a3d1-0397-4ba2-9588-b03cde16e5a5" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e85a3d1-0397-4ba2-9588-b03cde16e5a5")) {                    Plotly.newPlot(                        "4e85a3d1-0397-4ba2-9588-b03cde16e5a5",                        [{"alignmentgroup":"True","base":["1970-01-04T20:00:00","1970-01-05T10:00:00","1970-01-05T20:00:00","1970-01-07T10:00:00","1970-01-07T22:00:00","1970-01-08T13:00:00","1970-01-23T00:00:00","1970-01-23T09:00:00","1970-01-23T16:00:00","1970-01-02T15:00:00","1970-01-03T02:00:00","1970-01-03T10:00:00","1970-01-15T05:00:00","1970-01-15T17:00:00","1970-01-16T02:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j80-j0902","j81-j0902","j82-j0902","j80-j0903","j81-j0903","j82-j0903","j80-j0905","j81-j0905","j82-j0905","j80-j0901","j81-j0901","j82-j0901","j80-j0904","j81-j0904","j82-j0904"],"textposition":"auto","x":[50400000.0,36000000.0,36000000.0,43200000.0,28800000.0,36000000.0,32400000.0,25200000.0,25200000.0,39600000.0,28800000.0,28800000.0,43200000.0,32400000.0,32400000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M6","M6","M6","M6","M2","M2","M2","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-25T07:00:00","1970-01-25T21:00:00","1970-01-04T04:00:00","1970-01-02T18:00:00","1970-01-03T19:00:00","1970-01-04T03:00:00","1970-01-04T09:00:00","1970-01-01T14:00:00","1970-01-02T19:00:00","1970-01-03T03:00:00","1970-01-03T08:00:00","1970-01-03T13:00:00","1970-01-20T16:00:00","1970-01-21T06:00:00","1970-01-21T19:00:00","1970-01-22T08:00:00","1970-01-22T21:00:00","1970-01-25T23:00:00","1970-01-25T13:00:00","1970-01-25T07:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j70-j0804","j73-j0804","j73-j0802","j70-j0802","j71-j0802","j72-j0802","j74-j0802","j70-j0801","j71-j0801","j72-j0801","j73-j0801","j74-j0801","j70-j0803","j71-j0803","j72-j0803","j73-j0803","j74-j0803","j74-j0804","j72-j0804","j71-j0804"],"textposition":"auto","x":[50400000.0,43200000.0,25200000.0,32400000.0,28800000.0,21600000.0,21600000.0,32400000.0,28800000.0,18000000.0,18000000.0,18000000.0,50400000.0,46800000.0,46800000.0,46800000.0,46800000.0,61200000.0,57600000.0,57600000.0],"xaxis":"x","y":["M6","M6","M5","M4","M4","M4","M4","M3","M3","M3","M3","M3","M3","M3","M3","M3","M3","M3","M2","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-01T16:00:00","1970-01-01T23:00:00","1970-01-03T12:00:00","1970-01-22T01:00:00","1970-01-22T13:00:00","1970-01-02T11:00:00","1970-01-02T18:00:00","1970-01-02T23:00:00","1970-01-03T04:00:00","1970-01-03T09:00:00","1970-01-03T14:00:00","1970-01-23T23:00:00","1970-01-24T12:00:00","1970-01-24T22:00:00","1970-01-25T08:00:00","1970-01-02T07:00:00","1970-01-21T14:00:00","1970-01-22T06:00:00","1970-01-01T23:00:00","1970-01-02T07:00:00","1970-01-02T13:00:00","1970-01-15T07:00:00","1970-01-15T19:00:00","1970-01-16T06:00:00","1970-01-01T21:00:00","1970-01-03T13:00:00","1970-01-16T11:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j60-j0701","j61-j0701","j63-j0701","j61-j0704","j61-j0706","j63-j0706","j60-j0703","j61-j0703 ...
# 4
# FlowTime: 25181
# machine_util: 0
# util: 0.9579884105960265
# makespan: 861
# <div>                            <div id="3ac6357f-8286-4d25-a58b-130f46001b85" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ac6357f-8286-4d25-a58b-130f46001b85")) {                    Plotly.newPlot(                        "3ac6357f-8286-4d25-a58b-130f46001b85",                        [{"alignmentgroup":"True","base":["1970-01-14T15:00:00","1970-01-15T04:00:00","1970-01-15T14:00:00","1970-01-15T22:00:00","1970-01-16T07:00:00","1970-01-14T07:00:00","1970-01-14T20:00:00","1970-01-15T09:00:00","1970-01-15T21:00:00","1970-01-16T11:00:00","1970-01-14T12:00:00","1970-01-15T02:00:00","1970-01-15T13:00:00","1970-01-15T22:00:00","1970-01-16T07:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j82-j0901","j82-j0902","j82-j0903","j82-j0904","j82-j0905","j80-j0901","j80-j0902","j80-j0903","j80-j0904","j80-j0905","j81-j0901","j81-j0902","j81-j0903","j81-j0904","j81-j0905"],"textposition":"auto","x":[46800000.0,36000000.0,28800000.0,32400000.0,25200000.0,46800000.0,46800000.0,43200000.0,50400000.0,54000000.0,50400000.0,39600000.0,32400000.0,32400000.0,75600000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M3","M3","M3","M3","M3","M1","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-05T01:00:00","1970-01-05T17:00:00","1970-01-06T04:00:00","1970-01-06T15:00:00","1970-01-05T00:00:00","1970-01-05T11:00:00","1970-01-05T16:00:00","1970-01-06T10:00:00","1970-01-05T04:00:00","1970-01-05T21:00:00","1970-01-06T03:00:00","1970-01-06T22:00:00","1970-01-05T15:00:00","1970-01-05T21:00:00","1970-01-06T09:00:00","1970-01-06T22:00:00","1970-01-05T13:00:00","1970-01-06T01:00:00","1970-01-06T11:00:00","1970-01-07T07:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j71-j0801","j71-j0802","j71-j0803","j71-j0804","j70-j0801","j70-j0802","j70-j0803","j70-j0804","j72-j0801","j72-j0802","j72-j0803","j72-j0804","j74-j0801","j74-j0802","j74-j0803","j74-j0804","j73-j0801","j73-j0802","j73-j0803","j73-j0804"],"textposition":"auto","x":[57600000.0,39600000.0,39600000.0,43200000.0,39600000.0,18000000.0,64800000.0,54000000.0,61200000.0,21600000.0,68400000.0,72000000.0,21600000.0,43200000.0,46800000.0,54000000.0,43200000.0,36000000.0,72000000.0,50400000.0],"xaxis":"x","y":["M6","M6","M6","M6","M5","M5","M5","M5","M4","M4","M4","M4","M3","M3","M3","M3","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-27T21:00:00","1970-01-28T05:00:00","1970-01-28T23:00:00","1970-01-29T15:00:00","1970-01-29T22:00:00","1970-01-30T21:00:00","1970-01-31T08:00:00","1970-01-25T06:00:00","1970-01-25T22:00:00","1970-01-26T07:00:00","1970-01-26T12:00:00","1970-01-26T17:00:00","1970-01-27T11:00:00","1970-01-28T04:00:00","1970-01-28T13:00:00","1970-01-29T00:00:00","1970-01-29T15:00:00","1970-01-30T01:00:00","1970-01-30T10:00:00","1970-01-30T21:00:00","1970-01-31T13:00:00","1970-01-26T22:00:00","1970-01-27T07:00:00","1970-01-28T00:00:00","1970-01-28T14:00:00","1970-01-28T20:00:00","1970-01-29T10:00:00","1970-01-30T04:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j62-j0701","j62-j0702","j62-j0703","j62-j0704","j62-j0705","j62-j0706","j62-j0707","j60-j0701 ...
# 5
# FlowTime: 48106
# machine_util: 0
# util: 0.9402810304449649
# makespan: 1013
# <div>                            <div id="11024f7c-e068-4348-9bb0-4db81d3309a8" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11024f7c-e068-4348-9bb0-4db81d3309a8")) {                    Plotly.newPlot(                        "11024f7c-e068-4348-9bb0-4db81d3309a8",                        [{"alignmentgroup":"True","base":["1970-01-30T15:00:00","1970-01-31T08:00:00","1970-01-31T21:00:00","1970-02-01T10:00:00","1970-02-01T11:00:00","1970-02-02T23:00:00","1970-02-03T10:00:00","1970-02-04T04:00:00","1970-02-05T08:00:00","1970-02-05T19:00:00","1970-02-06T13:00:00","1970-02-07T01:00:00","1970-02-07T10:00:00","1970-02-08T04:00:00","1970-02-05T02:00:00","1970-02-05T14:00:00","1970-02-06T10:00:00","1970-02-07T00:00:00","1970-02-07T10:00:00","1970-02-08T06:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j70-j0801","j71-j0801","j72-j0801","j73-j0801","j74-j0801","j70-j0802","j70-j0803","j70-j0804","j72-j0802","j72-j0803","j72-j0804","j74-j0802","j74-j0803","j74-j0804","j71-j0802","j71-j0803","j71-j0804","j73-j0802","j73-j0803","j73-j0804"],"textposition":"auto","x":[61200000.0,46800000.0,46800000.0,46800000.0,57600000.0,39600000.0,64800000.0,43200000.0,39600000.0,64800000.0,43200000.0,32400000.0,64800000.0,43200000.0,43200000.0,72000000.0,50400000.0,36000000.0,72000000.0,50400000.0],"xaxis":"x","y":["M6","M6","M6","M6","M4","M2","M2","M2","M2","M2","M2","M2","M2","M2","M1","M1","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-18T21:00:00","1970-01-19T18:00:00","1970-01-25T05:00:00","1970-01-27T12:00:00","1970-01-17T04:00:00","1970-01-17T20:00:00","1970-01-18T09:00:00","1970-01-18T22:00:00","1970-01-24T21:00:00","1970-01-25T16:00:00","1970-01-26T10:00:00","1970-01-20T13:00:00","1970-01-21T09:00:00","1970-01-23T20:00:00","1970-01-24T11:00:00","1970-01-25T01:00:00","1970-01-25T15:00:00","1970-01-26T05:00:00","1970-01-26T18:00:00","1970-01-27T09:00:00","1970-01-20T06:00:00","1970-01-25T22:00:00","1970-01-26T21:00:00","1970-01-19T08:00:00","1970-01-20T02:00:00","1970-01-26T17:00:00","1970-01-27T10:00:00","1970-01-21T12:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j60-j0702","j62-j0702","j61-j0705","j63-j0707","j60-j0701","j61-j0701","j62-j0701","j63-j0701","j60-j0705","j62-j0705","j61-j0706","j61-j0703","j62-j0703","j60-j0704","j61-j0704","j62-j0704","j63-j0704","j63-j0705","j63-j0706","j61-j0707","j60-j0703","j60-j0706","j60-j0707","j61-j0702","j63-j0702","j62-j0706","j62-j0707","j63-j0703"],"textposition":"auto","x":[75600000.0,64800000.0,90000000.0,68400000.0,57600000.0,46800000.0,46800000.0,46800000.0,68400000.0,64800000.0,61200000.0,72000000.0,68400000.0,54000000.0,50400000.0,50400000.0,50400000.0,46800000.0,54000000.0,61200000.0,61200000.0,82800000.0,57600000.0,64800000.0,54000000.0,61200000.0,72000000.0,54000000.0],"xaxis":"x","y":["M6","M6","M6","M6","M5","M5","M5","M5","M5","M5","M5","M4","M4","M4","M4","M4","M4","M4","M4","M4","M3","M3","M3","M2","M2","M2","M2","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-08T21:00:00","1970-01-09T15:00:00","1970-01-26T06:00:00","1970-01-26T22:00:00","1970-01-28T07:00:00","1970-01-29T21:00:00","1970-01-31T13:00:00","1970-01-27T13:00:00","1970-01-28T08:00:00","1970-01-30T18:00:00"],"hovertemplate":"Type=j4<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<ex ...
# 6
# FlowTime: 26939
# machine_util: 0
# util: 0.9652155800874818
# makespan: 825
# <div>                            <div id="23c93809-463d-4e70-8e6b-747b768519c7" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23c93809-463d-4e70-8e6b-747b768519c7")) {                    Plotly.newPlot(                        "23c93809-463d-4e70-8e6b-747b768519c7",                        [{"alignmentgroup":"True","base":["1970-01-11T11:00:00","1970-01-11T23:00:00","1970-01-12T09:00:00","1970-01-12T17:00:00","1970-01-13T02:00:00","1970-01-11T08:00:00","1970-01-11T19:00:00","1970-01-12T06:00:00","1970-01-12T18:00:00","1970-01-13T06:00:00","1970-01-11T12:00:00","1970-01-12T02:00:00","1970-01-12T13:00:00","1970-01-12T22:00:00","1970-01-13T07:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j81-j0901","j81-j0902","j81-j0903","j81-j0904","j81-j0905","j80-j0901","j80-j0902","j80-j0903","j80-j0904","j80-j0905","j82-j0901","j82-j0902","j82-j0903","j82-j0904","j82-j0905"],"textposition":"auto","x":[43200000.0,36000000.0,28800000.0,32400000.0,25200000.0,39600000.0,39600000.0,43200000.0,43200000.0,54000000.0,50400000.0,39600000.0,32400000.0,32400000.0,75600000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M2","M2","M2","M2","M2","M1","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-02-02T06:00:00","1970-02-02T21:00:00","1970-02-02T06:00:00","1970-02-02T14:00:00","1970-02-02T19:00:00","1970-01-31T19:00:00","1970-02-01T10:00:00","1970-02-01T16:00:00","1970-02-02T11:00:00","1970-02-03T08:00:00","1970-01-29T22:00:00","1970-01-30T10:00:00","1970-01-30T20:00:00","1970-01-31T16:00:00","1970-02-01T06:00:00","1970-02-01T15:00:00","1970-02-02T01:00:00","1970-02-02T21:00:00","1970-02-03T13:00:00","1970-02-04T04:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j73-j0801","j73-j0802","j74-j0801","j74-j0802","j74-j0803","j71-j0801","j71-j0802","j71-j0803","j71-j0804","j73-j0803","j70-j0801","j70-j0802","j70-j0803","j70-j0804","j72-j0801","j72-j0802","j72-j0803","j72-j0804","j74-j0804","j73-j0804"],"textposition":"auto","x":[54000000.0,39600000.0,28800000.0,18000000.0,64800000.0,54000000.0,21600000.0,68400000.0,72000000.0,72000000.0,43200000.0,36000000.0,72000000.0,50400000.0,32400000.0,36000000.0,72000000.0,50400000.0,50400000.0,50400000.0],"xaxis":"x","y":["M6","M6","M5","M5","M5","M4","M4","M4","M4","M2","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-24T16:00:00","1970-01-25T02:00:00","1970-01-25T20:00:00","1970-01-26T12:00:00","1970-01-26T19:00:00","1970-01-27T18:00:00","1970-01-28T05:00:00","1970-01-26T08:00:00","1970-01-26T22:00:00","1970-01-27T07:00:00","1970-01-27T12:00:00","1970-01-27T17:00:00","1970-01-28T11:00:00","1970-01-29T04:00:00","1970-01-27T10:00:00","1970-01-28T05:00:00","1970-01-28T13:00:00","1970-01-29T08:00:00","1970-01-29T22:00:00","1970-01-30T11:00:00","1970-01-31T02:00:00","1970-01-25T23:00:00","1970-01-26T08:00:00","1970-01-27T01:00:00","1970-01-27T15:00:00","1970-01-27T21:00:00","1970-01-28T11:00:00","1970-01-29T05:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j60-j0701","j60-j0702","j60-j0703","j60-j0704","j60-j0705","j60-j0706","j60-j0707","j62-j0701 ...
# 7
# FlowTime: 55564
# machine_util: 0
# util: 0.8477584629460201
# makespan: 917
# <div>                            <div id="29a97ac4-1f88-46f7-bd74-65ab21de4b3a" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29a97ac4-1f88-46f7-bd74-65ab21de4b3a")) {                    Plotly.newPlot(                        "29a97ac4-1f88-46f7-bd74-65ab21de4b3a",                        [{"alignmentgroup":"True","base":["1970-01-17T06:00:00","1970-01-23T12:00:00","1970-01-11T20:00:00","1970-02-01T15:00:00","1970-01-26T05:00:00","1970-01-15T08:00:00","1970-01-13T07:00:00","1970-01-21T03:00:00","1970-01-27T21:00:00","1970-02-04T01:00:00","1970-02-06T11:00:00","1970-01-09T04:00:00","1970-01-10T15:00:00","1970-01-19T10:00:00","1970-01-29T18:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j82-j0902","j82-j0903","j82-j0901","j80-j0905","j80-j0904","j81-j0902","j80-j0902","j81-j0903","j81-j0904","j81-j0905","j82-j0905","j80-j0901","j81-j0901","j80-j0903","j82-j0904"],"textposition":"auto","x":[50400000.0,39600000.0,43200000.0,46800000.0,72000000.0,57600000.0,50400000.0,57600000.0,54000000.0,68400000.0,61200000.0,43200000.0,50400000.0,43200000.0,43200000.0],"xaxis":"x","y":["M6","M6","M5","M5","M4","M3","M2","M2","M2","M2","M2","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-06T09:00:00","1970-01-07T00:00:00","1970-01-12T17:00:00","1970-01-14T04:00:00","1970-01-22T08:00:00","1970-01-29T07:00:00","1970-01-31T01:00:00","1970-01-24T11:00:00","1970-02-06T10:00:00","1970-01-08T02:00:00","1970-01-16T02:00:00","1970-01-18T15:00:00","1970-01-05T11:00:00","1970-01-08T10:00:00","1970-01-11T10:00:00","1970-01-25T21:00:00","1970-02-01T13:00:00","1970-01-10T02:00:00","1970-01-20T16:00:00","1970-02-03T22:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j71-j0801","j72-j0801","j72-j0802","j73-j0802","j72-j0803","j70-j0804","j71-j0804","j73-j0803","j74-j0804","j73-j0801","j74-j0802","j70-j0803","j70-j0801","j74-j0801","j71-j0802","j74-j0803","j72-j0804","j70-j0802","j71-j0803","j73-j0804"],"textposition":"auto","x":[54000000.0,46800000.0,50400000.0,43200000.0,43200000.0,46800000.0,46800000.0,68400000.0,57600000.0,50400000.0,28800000.0,57600000.0,32400000.0,32400000.0,36000000.0,82800000.0,50400000.0,46800000.0,75600000.0,68400000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M6","M6","M5","M5","M4","M4","M3","M2","M2","M2","M2","M2","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T04:00:00","1970-01-04T04:00:00","1970-01-09T16:00:00","1970-01-10T21:00:00","1970-02-01T12:00:00","1970-02-06T09:00:00","1970-01-01T09:00:00","1970-01-03T13:00:00","1970-01-04T17:00:00","1970-01-06T15:00:00","1970-01-25T15:00:00","1970-01-05T18:00:00","1970-01-22T02:00:00","1970-01-24T11:00:00","1970-01-27T19:00:00","1970-02-03T18:00:00","1970-01-08T10:00:00","1970-01-13T23:00:00","1970-01-17T20:00:00","1970-01-01T09:00:00","1970-01-01T19:00:00","1970-01-02T05:00:00","1970-01-02T20:00:00","1970-01-16T01:00:00","1970-01-19T07:00:00","1970-01-30T11:00:00","1970-01-07T11:00:00","1970-01-11T23:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j63-j0701","j63-j0702","j61-j0704","j62-j0704","j61-j0707","j63-j0707","j61-j0701","j62-j0702 ...
# 8
# FlowTime: 25079
# machine_util: 0
# util: 0.9604825291181365
# makespan: 848
# <div>                            <div id="cb27852c-6d73-46a5-b075-0b3c2ac430c1" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb27852c-6d73-46a5-b075-0b3c2ac430c1")) {                    Plotly.newPlot(                        "cb27852c-6d73-46a5-b075-0b3c2ac430c1",                        [{"alignmentgroup":"True","base":["1970-01-10T14:00:00","1970-01-11T02:00:00","1970-01-11T12:00:00","1970-01-11T20:00:00","1970-01-12T05:00:00","1970-01-11T02:00:00","1970-01-11T16:00:00","1970-01-12T05:00:00","1970-01-12T17:00:00","1970-01-13T07:00:00","1970-01-10T08:00:00","1970-01-10T22:00:00","1970-01-11T09:00:00","1970-01-11T18:00:00","1970-01-12T03:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j81-j0901","j81-j0902","j81-j0903","j81-j0904","j81-j0905","j82-j0901","j82-j0902","j82-j0903","j82-j0904","j82-j0905","j80-j0901","j80-j0902","j80-j0903","j80-j0904","j80-j0905"],"textposition":"auto","x":[43200000.0,36000000.0,28800000.0,32400000.0,25200000.0,50400000.0,46800000.0,43200000.0,50400000.0,54000000.0,50400000.0,39600000.0,32400000.0,32400000.0,75600000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M3","M3","M3","M3","M3","M1","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-17T07:00:00","1970-01-18T00:00:00","1970-01-18T11:00:00","1970-01-18T22:00:00","1970-01-16T02:00:00","1970-01-16T11:00:00","1970-01-16T16:00:00","1970-01-17T10:00:00","1970-01-15T11:00:00","1970-01-16T00:00:00","1970-01-16T06:00:00","1970-01-17T01:00:00","1970-01-15T22:00:00","1970-01-16T08:00:00","1970-01-16T17:00:00","1970-01-17T11:00:00","1970-01-15T18:00:00","1970-01-16T06:00:00","1970-01-16T16:00:00","1970-01-17T12:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j74-j0801","j74-j0802","j74-j0803","j74-j0804","j73-j0801","j73-j0802","j73-j0803","j73-j0804","j70-j0801","j70-j0802","j70-j0803","j70-j0804","j72-j0801","j72-j0802","j72-j0803","j72-j0804","j71-j0801","j71-j0802","j71-j0803","j71-j0804"],"textposition":"auto","x":[61200000.0,39600000.0,39600000.0,43200000.0,32400000.0,18000000.0,64800000.0,54000000.0,46800000.0,21600000.0,68400000.0,72000000.0,36000000.0,32400000.0,64800000.0,43200000.0,43200000.0,36000000.0,72000000.0,50400000.0],"xaxis":"x","y":["M6","M6","M6","M6","M5","M5","M5","M5","M4","M4","M4","M4","M2","M2","M2","M2","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-26T07:00:00","1970-01-26T17:00:00","1970-01-27T11:00:00","1970-01-28T03:00:00","1970-01-28T10:00:00","1970-01-29T09:00:00","1970-01-29T20:00:00","1970-01-28T09:00:00","1970-01-28T23:00:00","1970-01-29T08:00:00","1970-01-29T13:00:00","1970-01-29T18:00:00","1970-01-30T12:00:00","1970-01-31T05:00:00","1970-01-29T07:00:00","1970-01-29T18:00:00","1970-01-30T09:00:00","1970-01-30T19:00:00","1970-01-31T04:00:00","1970-01-31T15:00:00","1970-01-27T21:00:00","1970-01-28T06:00:00","1970-01-28T23:00:00","1970-01-29T13:00:00","1970-01-29T19:00:00","1970-01-30T09:00:00","1970-01-31T03:00:00","1970-02-01T07:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j60-j0701","j60-j0702","j60-j0703","j60-j0704","j60-j0705","j60-j0706","j60-j0707","j62-j0701 ...
# 9
# FlowTime: 42005
# machine_util: 0
# util: 0.8625512868332712
# makespan: 939
# <div>                            <div id="7ebe776b-47af-4b04-8fbb-584e2edb93c6" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ebe776b-47af-4b04-8fbb-584e2edb93c6")) {                    Plotly.newPlot(                        "7ebe776b-47af-4b04-8fbb-584e2edb93c6",                        [{"alignmentgroup":"True","base":["1970-01-28T01:00:00","1970-01-30T20:00:00","1970-01-26T00:00:00","1970-01-30T21:00:00","1970-02-02T15:00:00","1970-01-26T00:00:00","1970-01-28T03:00:00","1970-01-23T23:00:00","1970-02-02T15:00:00","1970-01-23T23:00:00","1970-01-27T23:00:00","1970-01-31T00:00:00","1970-01-24T09:00:00","1970-01-25T19:00:00","1970-02-02T13:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j81-j0903","j80-j0904","j82-j0902","j81-j0904","j82-j0905","j81-j0902","j82-j0903","j80-j0901","j81-j0905","j81-j0901","j80-j0903","j82-j0904","j82-j0901","j80-j0902","j80-j0905"],"textposition":"auto","x":[39600000.0,46800000.0,72000000.0,54000000.0,46800000.0,64800000.0,54000000.0,43200000.0,68400000.0,39600000.0,57600000.0,57600000.0,46800000.0,50400000.0,86400000.0],"xaxis":"x","y":["M6","M6","M5","M5","M5","M4","M4","M3","M3","M2","M2","M2","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-03T05:00:00","1970-01-07T07:00:00","1970-01-10T07:00:00","1970-01-17T11:00:00","1970-01-21T04:00:00","1970-01-03T05:00:00","1970-01-04T14:00:00","1970-01-07T02:00:00","1970-01-13T22:00:00","1970-01-21T08:00:00","1970-01-07T04:00:00","1970-01-14T02:00:00","1970-01-03T06:00:00","1970-01-04T12:00:00","1970-01-07T05:00:00","1970-01-10T05:00:00","1970-01-13T20:00:00","1970-01-17T06:00:00","1970-01-03T07:00:00","1970-01-04T13:00:00","1970-01-13T20:00:00","1970-01-17T15:00:00","1970-01-21T03:00:00","1970-01-04T12:00:00","1970-01-10T02:00:00","1970-01-10T10:00:00","1970-01-17T10:00:00","1970-01-20T20:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j61-j0701","j63-j0703","j62-j0704","j62-j0706","j62-j0707","j60-j0701","j63-j0702","j60-j0703","j62-j0705","j63-j0707","j61-j0703","j63-j0705","j62-j0701","j61-j0702","j62-j0703","j61-j0704","j60-j0705","j60-j0706","j63-j0701","j62-j0702","j61-j0705","j63-j0706","j61-j0707","j60-j0702","j60-j0704","j63-j0704","j61-j0706","j60-j0707"],"textposition":"auto","x":[28800000.0,61200000.0,28800000.0,50400000.0,61200000.0,54000000.0,36000000.0,28800000.0,75600000.0,46800000.0,79200000.0,50400000.0,43200000.0,28800000.0,57600000.0,43200000.0,57600000.0,75600000.0,43200000.0,57600000.0,50400000.0,68400000.0,75600000.0,68400000.0,28800000.0,21600000.0,68400000.0,72000000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6","M5","M5","M5","M5","M5","M4","M4","M3","M3","M3","M3","M3","M3","M2","M2","M2","M2","M2","M1","M1","M1","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-13T17:00:00","1970-01-16T21:00:00","1970-01-13T05:00:00","1970-01-16T23:00:00","1970-01-20T16:00:00","1970-01-16T22:00:00","1970-01-20T15:00:00","1970-01-20T15:00:00","1970-01-13T11:00:00","1970-01-16T17:00:00","1970-01-13T18:00:00","1970-01-20T06:00:00"],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>ID_OP=%{text}<extra></extra>","legendgroup":"j6","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["j52-j0601","j51-j0602","j50-j0601","j53-j0602 ...
# [738, 1096, 923, 658, 861, 1013, 825, 917, 848, 939]
# [24710, 54856, 56345, 37694, 25181, 48106, 26939, 55564, 25079, 42005]
# [0.9053326810176126, 0.885376707073807, 0.8400217904485201, 0.8924897119341564, 0.9579884105960265, 0.9402810304449649, 0.9652155800874818, 0.8477584629460201, 0.9604825291181365, 0.8625512868332712]
