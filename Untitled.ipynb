# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Dec 27 13:33:05 2022

@author: parkh
"""
    
import pandas as pd
import numpy as np
from datetime import datetime
import plotly.express as px
import copy
import random
from matplotlib import pylab as plt
from Resource2 import *
from Job2 import *
from collections import defaultdict
    
    
class FJSP_simulator():
        
    def __init__(self, data, setup_data, k):
        self.k = k
        self.done = False
        self.event_list=[]
        self.process_time_table = pd.read_csv(data,index_col=(0))
        self.setup_time_table = pd.read_csv(setup_data, index_col=(0))
        self.machine_number = len(self.process_time_table.columns)
        """총 job 개수"""
        operation = self.process_time_table.index
        op_table=[]
        for i in range(len(operation)):
            op_table.append(operation[i][1:3])
        self.job_number = len(set(op_table))
        
        """각 job별로 총 operation개수"""
        self.max_operation=[0 for x in range(self.job_number)]
        for i in range(1, self.job_number+1):
            for j in op_table:
                if i == int(j):
                    self.max_operation[i-1] +=1
        self.num_of_op = sum(self.max_operation)
        """job 인스턴스 생성"""
        self.j_list = defaultdict(Job)
        for i in range(self.job_number):
            j = Job(i+1, self.max_operation[i],self.setup_time_table) 
            self.j_list[j.id] = j

        """machine 인스턴스 생성"""
        self.r_list = defaultdict(Resource)
        for i in range(self.machine_number):
            r = Resource("M"+str(i+1))
            self.r_list[r.id] = r
        self.time = 0 #시간
        self.end = True #종료조건
        self.j=0
        self.plotlydf = pd.DataFrame([],columns=['Type','Task','Start','Finish','Resource','Rule','Step'])
        self.step_number = 1
    def performance_measure(self):
        Flow_time = 0
        value_time_table = []
        full_time_table = []
        machine_util = 0
        util = 0
        makespan = self.time
        for machine in self.r_list:
            value_added_time, full_time = self.r_list[machine].util()
            value_time_table.append(value_added_time)
            full_time_table.append(full_time)
        util = sum(value_time_table)/sum(full_time_table)
        for job in self.j_list:
            Flow_time += self.j_list[job].job_flowtime
        return Flow_time, machine_util, util, makespan
    
    def gannt_chart(self):
        step_rule = []
        for i in range(len(self.plotlydf)):
            if str(self.plotlydf["Rule"].loc[i])  != "None":
                step_rule.append(str(self.plotlydf["Step"].loc[i])+"-"+str(self.plotlydf["Rule"].loc[i]))
            else:
                step_rule.append("NONE")
        self.plotlydf["Step-Rule"] = step_rule
        
        plotlydf2 = self.plotlydf.sort_values(by=['Resource','Type'], ascending=False)
        df = self.to_bottom_setup_df(plotlydf2) #setup 뒤로 보낸 데이터 프레임
        
        fig = px.timeline(df, x_start="Start", x_end="Finish", y="Resource", hover_data=['Rule'],template="simple_white",color="Type", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "Task", width=2000, height=800)
        fig.update_traces(marker=dict(line_color="black"))
        
        [(self.modify_width(bar, 0.7))
        for bar in fig.data if ('setup' in bar.legendgroup)]
        fig.show()
        
        #fig,write_html(f"{PathInfo.xlsx}{os.sep}temp_target.html", default_width=2300, default_height=900)
        plotlydf3 = self.plotlydf.sort_values(by=['Type'], ascending=True)
        fig2 = px.timeline(plotlydf3, x_start="Start", x_end="Finish", y="Type", template="seaborn" ,color="Resource",text = "Resource", width=2000, height=1000)
        fig2.update_traces(marker=dict(line_color="yellow", cmid = 1000))
        fig2.show()
        
        fig3 = px.timeline(df, x_start="Start", x_end="Finish", y="Resource", template="simple_white",color="Type", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "Rule", width=2000, height=800)
        [(self.modify_width(bar, 0.7), self.modify_text(bar)) for bar in fig3.data if ('setup' in bar.legendgroup)]
        fig3.show()
        
        
        fig4 = px.timeline(df, x_start="Start", x_end="Finish", y="Resource", template="simple_white",color="Type", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "Step-Rule", width=2000, height=800)
        [(self.modify_width(bar, 0.7), self.modify_text(bar))
        for bar in fig4.data if ('setup' in bar.legendgroup)]
        fig4.show()
        
        fig5 = px.timeline(df, x_start="Start", x_end="Finish", y="Rule", template="simple_white",color="Rule", color_discrete_sequence=px.colors.qualitative.Dark24 ,text = "Step-Rule", width=2000, height=800)
        fig5.show()   
        
    def modify_width(self, bar, width):
        """
        막대의 너비를 설정합니다.
        width = (단위 px)
        """
        bar.width = width
    def modify_text(self, bar):
        """
        막대의 텍스트를 설정합니다.
        width = (단위 px)
        """
        bar.text = ""
    def to_bottom_setup_df(self, df):
        """
        figure의 경우 위에서 부터 bar 생성됩니다.
        track_in event를 df(데이터프레임) 가장 밑 행으로 배치시킵니다.
        이 작업을 통해 TRACK_IN 이벤트가 다른 중복되는 차트에 가려지는 것을 방지합니다.
        """
        setup_df = df.loc[df['Type'] == 'setup']
        df = df[df['Type'] != 'setup']
        df = df.append(setup_df, ignore_index=True)
        return df
    
    def check_availability(self):
        index_k = 0
        select_machine = "NONE"
        for machine in self.r_list:
            index_k += 1
            if self.r_list[machine].status == 0:
                machine = self.r_list[machine].id #machine 이름
                p_table=[]
                for job in self.j_list: #job 이름과 operation이름 찾기
                    jop = self.j_list[job].jop()
                    if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                        pass
                    elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                        pass
                    elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                        pass
                    else: 
                        p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop]])
                if len(p_table) == 0:#현재 이벤트를 발생시킬 수 없음
                    pass
                else:
                    select_machine = machine
                    break
        return select_machine
    
    def run(self):
        while True:
            machine = self.check_availability()
            if machine != "NONE":
                p_time = self.dispatching_rule_decision(machine, self.k)
            else:
                if len(self.event_list) == 0:
                    break
                self.process_event()
                
        Flow_time, machine_util, util, makespan = self.performance_measure()
        print("FlowTime:" , Flow_time)
        print("machine_util:" , machine_util)
        print("util:" , util)
        print("makespan:" , makespan)
        print(self.num_of_op)
        self.gannt_chart()
        return Flow_time, util, makespan
    #event = (job_type, operation, machine_type, start_time, end_time, event_type)
    def dispatching_rule_decision(self,machine, a):
        #print(machine)
        if a == "random":
            coin = random.randint(0,5)
        else:
            coin = int(a)
        if coin == 0:
            p_time = self.dispatching_rule_SPT(machine)
        elif coin == 1:
            p_time = self.dispatching_rule_SPTSSU(machine)
        elif coin == 2:
            p_time = self.dispatching_rule_MOR(machine)
        elif coin == 3:
            p_time = self.dispatching_rule_MORSPT(machine)
        elif coin == 4:
            p_time = self.dispatching_rule_LOR(machine)
        elif coin == 5:
            p_time = self.dispatching_rule_LPT(machine)
        return p_time
        
    def process_event(self):
        self.event_list.sort(key = lambda x:x[4], reverse = False)
        event = self.event_list.pop(0)
        self.time = event[4]
        setup_time = event[8]
        job = event[0]
        machine = event[2]
        time = event[3]
        start = datetime.fromtimestamp(time*3600)
        time = event[4]
        end = datetime.fromtimestamp(time*3600)
        if event[5] == "setup_change":
            event_type = "setup"
        else:
            event_type = "j"+str(event[0].id)
            job.complete_setting(event[3]+setup_time, event[4],event[5]) # 작업이 대기로 변함, 시작시간, 종료시간, event_type
            machine.complete_setting(event[3]+setup_time,event[4],event[5]) # 기계도 사용가능하도록 변함
            #self.dispatching_rule_decision("random")
            self.num_of_op -=1
        rule = event[6]
        step = event[7]
        operation = event[1]
        self.plotlydf.loc[self.j] = dict(Type = event_type, Task=operation, Start=start, Finish=end, Resource=machine.id, Rule = rule, Step = step) #간트차트를 위한 딕셔너리 생성, 데이터프레임에 집어넣음
        self.j+=1
        if self.num_of_op == 0:
            done = True
        else:
            done = False
        return done
    
    def assign_setting(self, job, machine, reservation_time): #job = 1 machine = 1
        job.assign_setting(machine)
        machine.assign_setting(job, reservation_time)
        
    def complete_setting(self, job, machine):
        job.complete_setting()
        machine.complete_setting()
    def check_availability(self):
        index_k = 0
        select_machine = "NONE"
        for machine in self.r_list:
            index_k += 1
            if self.r_list[machine].status == 0:
                machine = self.r_list[machine].id #machine 이름
                p_table=[]
                for job in self.j_list: #job 이름과 operation이름 찾기
                    jop = self.j_list[job].jop()
                    if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                        pass
                    elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                        pass
                    elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                        pass
                    else: 
                        p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop]])
                if len(p_table) == 0:#현재 이벤트를 발생시킬 수 없음
                    pass
                else:
                    select_machine = machine
                    break
        return select_machine
                
    def dispatching_rule_SPT(self, machine):
        rule_name= "SPT"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        if len(p_table) == 0:#현재 이벤트를 발생시킬 수 없음
            pass
        else:
            p_table.sort(key = lambda x:x[1], reverse = False)
            setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
            jop = p_table[0][2]
            if setup_time !=0:
                self.event_list.append((p_table[0][0],"setup" , self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
            self.event_list.append((p_table[0][0], jop ,self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
            self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
    
    def dispatching_rule_LPT(self, machine):
        rule_name= "LPT"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:x[1], reverse = True)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop, self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish", rule_name, step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
        
    def dispatching_rule_SPTSSU(self, machine):
        rule_name= "SPTSSU"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            setup_time = self.j_list[job].setup_table['j'+str(self.r_list[machine].setup_status)]
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop]+setup_time, jop])
        p_table.sort(key = lambda x:x[1], reverse = False)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0], "setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop, self.r_list[machine], self.time, self.time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0],self.r_list[machine],self.time+p_table[0][1])
        return p_table[0][1] - setup_time
            
    def dispatching_rule_MOR(self,machine):
        rule_name= "MOR"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:x[0].remain_operation, reverse = True)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0],jop, self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
            
    def dispatching_rule_MORSPT(self, machine):
        rule_name= "MORSPT"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x : x[1]/x[0].remain_operation, reverse = False)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0], "setup",self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop,self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
        
            
    def dispatching_rule_LOR(self,machine):
        rule_name= "LOR"
        step_num = self.step_number
        self.step_number+=1
        machine = self.r_list[machine].id #machine 이름
        p_table=[]
        for job in self.j_list: #job 이름과 operation이름 찾기
            jop = self.j_list[job].jop()
            if jop not in self.process_time_table.index: #해당 jop가 없는 경우  
                pass
            elif self.process_time_table[machine].loc[jop] == 0 : #해당 jop가 작업이 불가능할 경우
                pass
            elif self.j_list[job].status != "WAIT": #해당 jop가 작업중일 경우
                pass
            else: 
                p_table.append([self.j_list[job], self.process_time_table[machine].loc[jop],jop])
        p_table.sort(key = lambda x:x[0].remain_operation, reverse = False)
        setup_time = p_table[0][0].setup_table['j'+str(self.r_list[machine].setup_status)] #컬럼에서 machine에 세팅되어있던 job에서 변경유무 확인
        jop = p_table[0][2]
        if setup_time !=0:
            self.event_list.append((p_table[0][0],"setup", self.r_list[machine], self.time, self.time+setup_time,"setup_change","NONE",step_num,setup_time))
        self.event_list.append((p_table[0][0], jop,self.r_list[machine], self.time, self.time+setup_time+p_table[0][1],"track_in_finish",rule_name,step_num,setup_time))
        self.assign_setting(p_table[0][0], self.r_list[machine],self.time+setup_time+p_table[0][1])
        return p_table[0][1]
#6, 2, 4, 5, 5, 2, 3, 2, 5, 4, 5       
#6, 5, 4, 5, 6, 5, 3, 7, 5, 6, 5
makespan_table = []
util = []
ft_table = []

for i in range(6):
    main = FJSP_simulator('C:/Users\parkh/git_tlsgudcks/simulator/data/FJSP_SIM7_all.csv','C:/Users/parkh/FJSP_SETUP_SIM.csv',i)
    FT, util2, ms = main.run()
    makespan_table.append(ms)
    util.append(util2)
    ft_table.append(FT)
print(min(makespan_table))
print(min(ft_table))
print(max(util))
print(sum(makespan_table)/1000)
print(sum(ft_table)/1000)
print(sum(util)/1000)

#main = FJSP_simulator('C:/Users/parkh/FJSP_SIM.csv','C:/Users/parkh/FJSP_SETUP_SIM.csv',"random")
#main.run()
#main.printer()
# Out:
# FlowTime: 2629
# machine_util: 0
# util: 0.8866877971473851
# makespan: 263
# 0
# <div>                            <div id="2d6ca4c0-501a-4443-b402-e90b9a47948f" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d6ca4c0-501a-4443-b402-e90b9a47948f")) {                    Plotly.newPlot(                        "2d6ca4c0-501a-4443-b402-e90b9a47948f",                        [{"alignmentgroup":"True","base":["1970-01-03T13:00:00","1970-01-04T01:00:00","1970-01-01T17:00:00","1970-01-01T09:00:00"],"customdata":[["SPT"],["SPT"],["SPT"],["SPT"]],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j8","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black"}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["j0803","j0804","j0802","j0801"],"textposition":"auto","x":[43200000.0,43200000.0,32400000.0,18000000.0],"xaxis":"x","y":["M6","M6","M5","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-05T09:00:00","1970-01-06T14:00:00","1970-01-02T01:00:00","1970-01-02T15:00:00","1970-01-03T02:00:00","1970-01-04T01:00:00","1970-01-01T14:00:00"],"customdata":[["SPT"],["SPT"],["SPT"],["SPT"],["SPT"],["SPT"],["SPT"]],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j7","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black"}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j0706","j0707","j0702","j0703","j0704","j0705","j0701"],"textposition":"auto","x":[50400000.0,64800000.0,32400000.0,39600000.0,32400000.0,50400000.0,36000000.0],"xaxis":"x","y":["M6","M6","M3","M2","M2","M2","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T12:00:00","1970-01-01T09:00:00","1970-01-03T07:00:00"],"customdata":[["SPT"],["SPT"],["SPT"]],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j6","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black"}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["j0602","j0601","j0603"],"textposition":"auto","x":[46800000.0,32400000.0,54000000.0],"xaxis":"x","y":["M6","M4","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T20:00:00","1970-01-02T02:00:00"],"customdata":[["SPT"],["SPT"],["SPT"],["SPT"]],"hovertemplate":"Type=j3<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j3","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black"}},"name":"j3","offsetgroup":"j3","orientation":"h","showlegend":true,"text":["j0301","j0302","j0303","j0304"],"textposition":"auto","x":[18000000.0,21600000.0,21600000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-07T08:00:00","1970-01-08T02:00:00","1970-01-08T12:00:00","1970-01-09T03:00:00","1970-01-09T17:00:00","1970-01-10T06:00:00"],"customdata":[["SPT"],["SPT"],["SPT"],["SPT"],["SPT"],["SPT"]],"hovertemplate":"Type=j20<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j20","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black"}},"name":"j20","offsetgroup":"j20","orientation":"h","showlegend":true,"text":["j2001","j2002","j2003","j2004","j2005","j2006"],"textposition":"auto","x":[64800000.0,36000000.0,54000000.0,50400000.0,46800000.0,43200000.0],"xaxis":"x","y":["M6","M6","M4","M4","M2","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-05T23 ...
# <div>                            <div id="7ec13550-d0bc-4218-ab77-94aadf32c4ce" class="plotly-graph-div" style="height:1000px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ec13550-d0bc-4218-ab77-94aadf32c4ce")) {                    Plotly.newPlot(                        "7ec13550-d0bc-4218-ab77-94aadf32c4ce",                        [{"alignmentgroup":"True","base":["1970-01-02T22:00:00","1970-01-01T18:00:00","1970-01-02T08:00:00","1970-01-02T14:00:00","1970-01-07T16:00:00","1970-01-04T15:00:00","1970-01-06T03:00:00","1970-01-05T09:00:00","1970-01-06T16:00:00","1970-01-07T04:00:00","1970-01-04T02:00:00","1970-01-03T09:00:00","1970-01-08T12:00:00","1970-01-09T03:00:00","1970-01-01T09:00:00","1970-01-07T16:00:00","1970-01-08T12:00:00","1970-01-01T18:00:00","1970-01-04T15:00:00","1970-01-05T09:00:00","1970-01-06T16:00:00","1970-01-03T09:00:00"],"hovertemplate":"Resource=%{text}<br>Start=%{base}<br>Finish=%{x}<br>Type=%{y}<extra></extra>","legendgroup":"M4","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""},"line":{"color":"yellow"},"cmid":1000},"name":"M4","offsetgroup":"M4","orientation":"h","showlegend":true,"text":["M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4"],"textposition":"auto","x":[39600000.0,50400000.0,21600000.0,28800000.0,68400000.0,64800000.0,46800000.0,64800000.0,43200000.0,43200000.0,46800000.0,61200000.0,54000000.0,50400000.0,32400000.0,3600000.0,10800000.0,7200000.0,14400000.0,10800000.0,10800000.0,10800000.0],"xaxis":"x","y":["j1","j1","j1","j1","j13","j15","j17","j17","j18","j18","j19","j19","j20","j20","j6","setup","setup","setup","setup","setup","setup","setup"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-03T22:00:00","1970-01-06T16:00:00","1970-01-07T01:00:00","1970-01-07T09:00:00","1970-01-05T17:00:00","1970-01-06T09:00:00","1970-01-07T21:00:00","1970-01-08T14:00:00","1970-01-09T06:00:00","1970-01-09T20:00:00","1970-01-02T00:00:00","1970-01-05T05:00:00","1970-01-04T12:00:00","1970-01-02T08:00:00","1970-01-10T03:00:00","1970-01-02T20:00:00","1970-01-11T05:00:00","1970-01-03T07:00:00","1970-01-01T14:00:00","1970-01-07T21:00:00","1970-01-01T14:00:00","1970-01-10T03:00:00","1970-01-03T07:00:00","1970-01-04T12:00:00","1970-01-03T22:00:00","1970-01-02T00:00:00","1970-01-05T17:00:00","1970-01-02T08:00:00"],"hovertemplate":"Resource=%{text}<br>Start=%{base}<br>Finish=%{x}<br>Type=%{y}<extra></extra>","legendgroup":"M1","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""},"line":{"color":"yellow"},"cmid":1000},"name":"M1","offsetgroup":"M1","orientation":"h","showlegend":true,"text":["M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1"],"textposition":"auto","x":[18000000.0,50400000.0,32400000.0,28800000.0,43200000.0,57600000.0,25200000.0,61200000.0,57600000.0,50400000.0,18000000.0,28800000.0,43200000.0,61200000.0,43200000.0,93600000.0,39600000.0,97200000.0,54000000.0,36000000.0,10800000.0,14400000.0,7200000.0,14400000.0,10800000.0,10800000.0,7200000.0,7200000.0,7200000.0],"xaxis":"x","y":["j10","j10","j11","j11","j11","j11","j11","j16","j16","j16","j16","j16","j18","j18","j2","j2","j2","j2","j6","j7","setup","setup","setup","setup","setup","setup","setup","setup","setup"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T18:00:00","1970-01-03T07:00:00","1970-01-01T14:00:00","1970-01-03T14:00:00","1970-01-02T10:00:00","1970-01-06T06:00:00","1970-01-06T22:00:00","1970-01-07T11:00:00","1970-01-08T10:00:00","1970-01-09T02:00:00","1970-01-05T12:00:00","1970-01-04T16:00:00","1970-01-06T01:00:00","1970-01-05T06:00:00","1970-01-04T01:00:00","1970-01-02T01:00:00","1970-01-01T09:00:00","1970-01-07T ...
# <div>                            <div id="a757eaa8-f129-400d-9d1d-170fa5ec0eb6" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a757eaa8-f129-400d-9d1d-170fa5ec0eb6")) {                    Plotly.newPlot(                        "a757eaa8-f129-400d-9d1d-170fa5ec0eb6",                        [{"alignmentgroup":"True","base":["1970-01-03T13:00:00","1970-01-04T01:00:00","1970-01-01T17:00:00","1970-01-01T09:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["SPT","SPT","SPT","SPT"],"textposition":"auto","x":[43200000.0,43200000.0,32400000.0,18000000.0],"xaxis":"x","y":["M6","M6","M5","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-05T09:00:00","1970-01-06T14:00:00","1970-01-02T01:00:00","1970-01-02T15:00:00","1970-01-03T02:00:00","1970-01-04T01:00:00","1970-01-01T14:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["SPT","SPT","SPT","SPT","SPT","SPT","SPT"],"textposition":"auto","x":[50400000.0,64800000.0,32400000.0,39600000.0,32400000.0,50400000.0,36000000.0],"xaxis":"x","y":["M6","M6","M3","M2","M2","M2","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T12:00:00","1970-01-01T09:00:00","1970-01-03T07:00:00"],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j6","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["SPT","SPT","SPT"],"textposition":"auto","x":[46800000.0,32400000.0,54000000.0],"xaxis":"x","y":["M6","M4","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T20:00:00","1970-01-02T02:00:00"],"hovertemplate":"Type=j3<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j3","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"j3","offsetgroup":"j3","orientation":"h","showlegend":true,"text":["SPT","SPT","SPT","SPT"],"textposition":"auto","x":[18000000.0,21600000.0,21600000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-07T08:00:00","1970-01-08T02:00:00","1970-01-08T12:00:00","1970-01-09T03:00:00","1970-01-09T17:00:00","1970-01-10T06:00:00"],"hovertemplate":"Type=j20<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j20","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"j20","offsetgroup":"j20","orientation":"h","showlegend":true,"text":["SPT","SPT","SPT","SPT","SPT","SPT"],"textposition":"auto","x":[64800000.0,36000000.0,54000000.0,50400000.0,46800000.0,43200000.0],"xaxis":"x","y":["M6","M6","M4","M4","M2","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-05T23:00:00","1970-01-06T16:00:00","1970-01-07T04:00:00","1970-01-04T12:00:00","1970-01-05T05:00:00"],"hovertemplate":"Type=j18<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j18","marker":{"color":"#222A2A","pattern":{"shape":""}},"name":"j18","offsetgroup":"j18","orientation":"h","showlegend":true,"text":["SPT","SPT","SPT","SPT","SPT"],"textposition":"auto","x":[54000000.0,43200000.0,43200000.0,61200000.0,43200000.0],"xaxis":"x","y":["M6","M4","M4","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","bas ...
# <div>                            <div id="72177dce-9385-4ff5-8f10-80e5eb17d08b" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72177dce-9385-4ff5-8f10-80e5eb17d08b")) {                    Plotly.newPlot(                        "72177dce-9385-4ff5-8f10-80e5eb17d08b",                        [{"alignmentgroup":"True","base":["1970-01-03T13:00:00","1970-01-04T01:00:00","1970-01-01T17:00:00","1970-01-01T09:00:00"],"hovertemplate":"Type=j8<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j8","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j8","offsetgroup":"j8","orientation":"h","showlegend":true,"text":["37-SPT","42-SPT","11-SPT","3-SPT"],"textposition":"auto","x":[43200000.0,43200000.0,32400000.0,18000000.0],"xaxis":"x","y":["M6","M6","M5","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-05T09:00:00","1970-01-06T14:00:00","1970-01-02T01:00:00","1970-01-02T15:00:00","1970-01-03T02:00:00","1970-01-04T01:00:00","1970-01-01T14:00:00"],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j7","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["55-SPT","69-SPT","17-SPT","25-SPT","31-SPT","41-SPT","7-SPT"],"textposition":"auto","x":[50400000.0,64800000.0,32400000.0,39600000.0,32400000.0,50400000.0,36000000.0],"xaxis":"x","y":["M6","M6","M3","M2","M2","M2","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T12:00:00","1970-01-01T09:00:00","1970-01-03T07:00:00"],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j6","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["23-SPT","4-SPT","33-SPT"],"textposition":"auto","x":[46800000.0,32400000.0,54000000.0],"xaxis":"x","y":["M6","M4","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T20:00:00","1970-01-02T02:00:00"],"hovertemplate":"Type=j3<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j3","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"j3","offsetgroup":"j3","orientation":"h","showlegend":true,"text":["6-SPT","10-SPT","14-SPT","19-SPT"],"textposition":"auto","x":[18000000.0,21600000.0,21600000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-07T08:00:00","1970-01-08T02:00:00","1970-01-08T12:00:00","1970-01-09T03:00:00","1970-01-09T17:00:00","1970-01-10T06:00:00"],"hovertemplate":"Type=j20<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j20","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"j20","offsetgroup":"j20","orientation":"h","showlegend":true,"text":["78-SPT","86-SPT","89-SPT","94-SPT","96-SPT","99-SPT"],"textposition":"auto","x":[64800000.0,36000000.0,54000000.0,50400000.0,46800000.0,43200000.0],"xaxis":"x","y":["M6","M6","M4","M4","M2","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-05T23:00:00","1970-01-06T16:00:00","1970-01-07T04:00:00","1970-01-04T12:00:00","1970-01-05T05:00:00"],"hovertemplate":"Type=j18<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j18","marker":{"color":"#222A2A","pattern":{"shape":""}},"name":"j18","offsetgroup":"j18","orientation":"h","showlegend":true,"text":["61-SPT","70-SPT","76-SPT","46-SPT","52-SPT"],"textposition":"auto","x":[54000000.0,43200000.0,43200000.0,61200000 ...
# <div>                            <div id="1e2916a4-6f2c-4a85-aff3-8bfdc573c948" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e2916a4-6f2c-4a85-aff3-8bfdc573c948")) {                    Plotly.newPlot(                        "1e2916a4-6f2c-4a85-aff3-8bfdc573c948",                        [{"alignmentgroup":"True","base":["1970-01-03T13:00:00","1970-01-04T01:00:00","1970-01-05T09:00:00","1970-01-06T14:00:00","1970-01-02T12:00:00","1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T20:00:00","1970-01-02T02:00:00","1970-01-07T08:00:00","1970-01-08T02:00:00","1970-01-05T23:00:00","1970-01-03T01:00:00","1970-01-04T13:00:00","1970-01-01T09:00:00","1970-01-02T15:00:00","1970-01-03T09:00:00","1970-01-03T21:00:00","1970-01-01T17:00:00","1970-01-02T02:00:00","1970-01-06T18:00:00","1970-01-07T12:00:00","1970-01-08T00:00:00","1970-01-08T15:00:00","1970-01-08T20:00:00","1970-01-04T06:00:00","1970-01-05T00:00:00","1970-01-05T14:00:00","1970-01-06T02:00:00","1970-01-06T09:00:00","1970-01-01T09:00:00","1970-01-08T12:00:00","1970-01-09T03:00:00","1970-01-03T09:00:00","1970-01-04T02:00:00","1970-01-06T16:00:00","1970-01-07T04:00:00","1970-01-05T09:00:00","1970-01-06T03:00:00","1970-01-04T15:00:00","1970-01-07T16:00:00","1970-01-01T18:00:00","1970-01-02T08:00:00","1970-01-02T14:00:00","1970-01-02T22:00:00","1970-01-01T09:00:00","1970-01-02T01:00:00","1970-01-04T01:00:00","1970-01-04T16:00:00","1970-01-05T06:00:00","1970-01-05T12:00:00","1970-01-06T01:00:00","1970-01-07T11:00:00","1970-01-08T10:00:00","1970-01-09T02:00:00","1970-01-02T10:00:00","1970-01-06T06:00:00","1970-01-06T22:00:00","1970-01-03T14:00:00","1970-01-01T14:00:00","1970-01-02T18:00:00","1970-01-03T07:00:00","1970-01-02T00:00:00","1970-01-02T15:00:00","1970-01-03T02:00:00","1970-01-04T01:00:00","1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T19:00:00","1970-01-03T11:00:00","1970-01-09T17:00:00","1970-01-10T06:00:00","1970-01-06T17:00:00","1970-01-08T08:00:00","1970-01-05T13:00:00","1970-01-06T03:00:00","1970-01-07T07:00:00","1970-01-08T00:00:00","1970-01-04T15:00:00","1970-01-05T07:00:00","1970-01-01T14:00:00","1970-01-03T07:00:00","1970-01-02T08:00:00","1970-01-02T20:00:00","1970-01-10T03:00:00","1970-01-11T05:00:00","1970-01-04T12:00:00","1970-01-05T05:00:00","1970-01-02T00:00:00","1970-01-07T21:00:00","1970-01-08T14:00:00","1970-01-09T06:00:00","1970-01-09T20:00:00","1970-01-05T17:00:00","1970-01-06T09:00:00","1970-01-06T16:00:00","1970-01-07T01:00:00","1970-01-07T09:00:00","1970-01-01T09:00:00","1970-01-03T22:00:00"],"hovertemplate":"Rule=%{y}<br>Start=%{base}<br>Finish=%{x}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"SPT","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"SPT","offsetgroup":"SPT","orientation":"h","showlegend":true,"text":["37-SPT","42-SPT","55-SPT","69-SPT","23-SPT","6-SPT","10-SPT","14-SPT","19-SPT","78-SPT","86-SPT","61-SPT","30-SPT","47-SPT","5-SPT","26-SPT","34-SPT","39-SPT","11-SPT","18-SPT","73-SPT","81-SPT","85-SPT","91-SPT","92-SPT","45-SPT","51-SPT","59-SPT","63-SPT","68-SPT","4-SPT","89-SPT","94-SPT","35-SPT","44-SPT","70-SPT","76-SPT","56-SPT","64-SPT","49-SPT","82-SPT","12-SPT","20-SPT","24-SPT","29-SPT","3-SPT","17-SPT","43-SPT","50-SPT","53-SPT","57-SPT","62-SPT","80-SPT","88-SPT","93-SPT","22-SPT","66-SPT","74-SPT","38-SPT","9-SPT","27-SPT","32-SPT","16-SPT","25-SPT","31-SPT","41-SPT","2-SPT","8-SPT","13-SPT","36-SPT","96-SPT","99-SPT","72-SPT","87-SPT","58-SPT","65-SPT","77-SPT","84-SPT","48-SPT","54-SPT","7-SPT","33-SPT","21-SPT","28-SPT","98-SPT","100-SPT","46-SPT","52-SPT","15-SPT","83-SPT","90-SPT","95-SPT","97-SPT","60-SPT","67-SPT","71-SPT","75-SPT","79-SPT","1-SPT","40-SPT"],"textposition":"auto","x":[43200000.0,43200000.0,50400000.0,64800000.0,46800000.0,18000000.0,21 ...
# FlowTime: 2591
# machine_util: 0
# util: 0.9118329466357309
# makespan: 283
# 0
# <div>                            <div id="be158b41-53d9-4f58-9e4b-75515801e0a6" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be158b41-53d9-4f58-9e4b-75515801e0a6")) {                    Plotly.newPlot(                        "be158b41-53d9-4f58-9e4b-75515801e0a6",                        [{"alignmentgroup":"True","base":["1970-01-04T00:00:00","1970-01-01T09:00:00","1970-01-02T10:00:00","1970-01-03T00:00:00","1970-01-03T12:00:00"],"customdata":[["SPTSSU"],["SPTSSU"],["SPTSSU"],["SPTSSU"],["SPTSSU"]],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black"}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["j0905","j0901","j0902","j0903","j0904"],"textposition":"auto","x":[36000000.0,28800000.0,50400000.0,43200000.0,43200000.0],"xaxis":"x","y":["M6","M5","M2","M2","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T12:00:00","1970-01-03T01:00:00","1970-01-01T09:00:00"],"customdata":[["SPTSSU"],["SPTSSU"],["SPTSSU"]],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j6","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black"}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["j0602","j0603","j0601"],"textposition":"auto","x":[46800000.0,39600000.0,32400000.0],"xaxis":"x","y":["M6","M6","M4"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-04T10:00:00","1970-01-05T01:00:00","1970-01-05T13:00:00","1970-01-06T02:00:00","1970-01-06T09:00:00"],"customdata":[["SPTSSU"],["SPTSSU"],["SPTSSU"],["SPTSSU"],["SPTSSU"]],"hovertemplate":"Type=j5<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j5","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black"}},"name":"j5","offsetgroup":"j5","orientation":"h","showlegend":true,"text":["j0501","j0502","j0503","j0504","j0505"],"textposition":"auto","x":[54000000.0,43200000.0,46800000.0,25200000.0,43200000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T20:00:00","1970-01-02T02:00:00"],"customdata":[["SPTSSU"],["SPTSSU"],["SPTSSU"],["SPTSSU"]],"hovertemplate":"Type=j3<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j3","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black"}},"name":"j3","offsetgroup":"j3","orientation":"h","showlegend":true,"text":["j0301","j0302","j0303","j0304"],"textposition":"auto","x":[18000000.0,21600000.0,21600000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-06T21:00:00","1970-01-07T17:00:00","1970-01-08T03:00:00","1970-01-08T21:00:00","1970-01-09T08:00:00","1970-01-09T22:00:00"],"customdata":[["SPTSSU"],["SPTSSU"],["SPTSSU"],["SPTSSU"],["SPTSSU"],["SPTSSU"]],"hovertemplate":"Type=j20<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j20","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black"}},"name":"j20","offsetgroup":"j20","orientation":"h","showlegend":true,"text":["j2001","j2002","j2003","j2004","j2005","j2006"],"textposition":"auto","x":[72000000.0,36000000.0,64800000.0,39600000.0,50400000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M5","M3","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base": ...
# <div>                            <div id="212da0c3-e57c-48b0-98af-9ef933f1c1b2" class="plotly-graph-div" style="height:1000px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("212da0c3-e57c-48b0-98af-9ef933f1c1b2")) {                    Plotly.newPlot(                        "212da0c3-e57c-48b0-98af-9ef933f1c1b2",                        [{"alignmentgroup":"True","base":["1970-01-02T08:00:00","1970-01-02T22:00:00","1970-01-02T14:00:00","1970-01-01T18:00:00","1970-01-05T19:00:00","1970-01-07T16:00:00","1970-01-08T12:00:00","1970-01-07T03:00:00","1970-01-06T09:00:00","1970-01-04T15:00:00","1970-01-05T08:00:00","1970-01-03T09:00:00","1970-01-04T02:00:00","1970-01-01T09:00:00","1970-01-04T15:00:00","1970-01-03T09:00:00","1970-01-01T18:00:00","1970-01-06T09:00:00","1970-01-05T19:00:00"],"hovertemplate":"Resource=%{text}<br>Start=%{base}<br>Finish=%{x}<br>Type=%{y}<extra></extra>","legendgroup":"M4","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""},"line":{"color":"yellow"},"cmid":1000},"name":"M4","offsetgroup":"M4","orientation":"h","showlegend":true,"text":["M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4","M4"],"textposition":"auto","x":[21600000.0,39600000.0,28800000.0,50400000.0,50400000.0,72000000.0,86400000.0,46800000.0,64800000.0,61200000.0,39600000.0,61200000.0,46800000.0,32400000.0,3600000.0,10800000.0,7200000.0,10800000.0,7200000.0],"xaxis":"x","y":["j1","j1","j1","j1","j14","j17","j17","j17","j17","j18","j18","j19","j19","j6","setup","setup","setup","setup","setup"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-03T07:00:00","1970-01-01T09:00:00","1970-01-08T16:00:00","1970-01-09T21:00:00","1970-01-04T14:00:00","1970-01-05T01:00:00","1970-01-03T22:00:00","1970-01-05T18:00:00","1970-01-06T12:00:00","1970-01-08T08:00:00","1970-01-01T14:00:00","1970-01-07T18:00:00","1970-01-07T02:00:00","1970-01-10T22:00:00","1970-01-12T01:00:00","1970-01-02T08:00:00","1970-01-02T20:00:00","1970-01-01T23:00:00","1970-01-08T16:00:00","1970-01-03T22:00:00","1970-01-01T14:00:00","1970-01-10T22:00:00","1970-01-02T08:00:00","1970-01-01T23:00:00","1970-01-05T18:00:00","1970-01-03T07:00:00"],"hovertemplate":"Resource=%{text}<br>Start=%{base}<br>Finish=%{x}<br>Type=%{y}<extra></extra>","legendgroup":"M1","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""},"line":{"color":"yellow"},"cmid":1000},"name":"M1","offsetgroup":"M1","orientation":"h","showlegend":true,"text":["M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1","M1"],"textposition":"auto","x":[54000000.0,18000000.0,104400000.0,57600000.0,39600000.0,61200000.0,57600000.0,64800000.0,50400000.0,18000000.0,32400000.0,50400000.0,57600000.0,97200000.0,97200000.0,43200000.0,39600000.0,32400000.0,10800000.0,3600000.0,10800000.0,10800000.0,7200000.0,10800000.0,10800000.0,14400000.0],"xaxis":"x","y":["j10","j10","j13","j13","j14","j14","j14","j15","j16","j16","j16","j16","j16","j2","j2","j2","j2","j7","setup","setup","setup","setup","setup","setup","setup","setup"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T13:00:00","1970-01-02T01:00:00","1970-01-08T10:00:00","1970-01-06T12:00:00","1970-01-05T16:00:00","1970-01-07T16:00:00","1970-01-08T19:00:00","1970-01-07T07:00:00","1970-01-01T14:00:00","1970-01-04T02:00:00","1970-01-04T13:00:00","1970-01-05T03:00:00","1970-01-09T08:00:00","1970-01-09T22:00:00","1970-01-02T20:00:00","1970-01-03T11:00:00","1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-09T08:00:00","1970-01-04T02:00:00","1970-01-02T20:00:00","1970-01-02T01:00:00","1970-01-05T16:00:00"],"hovertemplate":"Resource=%{text}<br>Start=%{base}<br>Finish=%{x}<br>Type=%{y}<extra></extra>","legendgroup":"M3","marker":{"color":"rgb(85,168,10 ...
# <div>                            <div id="ff17fde1-476c-43aa-ae44-eb007a611539" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff17fde1-476c-43aa-ae44-eb007a611539")) {                    Plotly.newPlot(                        "ff17fde1-476c-43aa-ae44-eb007a611539",                        [{"alignmentgroup":"True","base":["1970-01-04T00:00:00","1970-01-01T09:00:00","1970-01-02T10:00:00","1970-01-03T00:00:00","1970-01-03T12:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["SPTSSU","SPTSSU","SPTSSU","SPTSSU","SPTSSU"],"textposition":"auto","x":[36000000.0,28800000.0,50400000.0,43200000.0,43200000.0],"xaxis":"x","y":["M6","M5","M2","M2","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T12:00:00","1970-01-03T01:00:00","1970-01-01T09:00:00"],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j6","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["SPTSSU","SPTSSU","SPTSSU"],"textposition":"auto","x":[46800000.0,39600000.0,32400000.0],"xaxis":"x","y":["M6","M6","M4"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-04T10:00:00","1970-01-05T01:00:00","1970-01-05T13:00:00","1970-01-06T02:00:00","1970-01-06T09:00:00"],"hovertemplate":"Type=j5<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j5","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j5","offsetgroup":"j5","orientation":"h","showlegend":true,"text":["SPTSSU","SPTSSU","SPTSSU","SPTSSU","SPTSSU"],"textposition":"auto","x":[54000000.0,43200000.0,46800000.0,25200000.0,43200000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T20:00:00","1970-01-02T02:00:00"],"hovertemplate":"Type=j3<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j3","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"j3","offsetgroup":"j3","orientation":"h","showlegend":true,"text":["SPTSSU","SPTSSU","SPTSSU","SPTSSU"],"textposition":"auto","x":[18000000.0,21600000.0,21600000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-06T21:00:00","1970-01-07T17:00:00","1970-01-08T03:00:00","1970-01-08T21:00:00","1970-01-09T08:00:00","1970-01-09T22:00:00"],"hovertemplate":"Type=j20<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j20","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"j20","offsetgroup":"j20","orientation":"h","showlegend":true,"text":["SPTSSU","SPTSSU","SPTSSU","SPTSSU","SPTSSU","SPTSSU"],"textposition":"auto","x":[72000000.0,36000000.0,64800000.0,39600000.0,50400000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M5","M3","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-03T12:00:00","1970-01-04T02:00:00","1970-01-05T18:00:00"],"hovertemplate":"Type=j15<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j15","marker":{"color":"#222A2A","pattern":{"shape":""}},"name":"j15","offsetgroup":"j15","orientation":"h","showlegend":true,"text":["SPTSSU","SPTSSU","SPTSSU"],"textposition":"auto","x":[43200000.0,39600000.0,64800000.0],"xaxis":"x","y":["M6","M3","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T17:00:00","1970-01-01T09:00:00","1970- ...
# <div>                            <div id="b21acd47-2058-4e40-be8f-185ecd6b1317" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b21acd47-2058-4e40-be8f-185ecd6b1317")) {                    Plotly.newPlot(                        "b21acd47-2058-4e40-be8f-185ecd6b1317",                        [{"alignmentgroup":"True","base":["1970-01-04T00:00:00","1970-01-01T09:00:00","1970-01-02T10:00:00","1970-01-03T00:00:00","1970-01-03T12:00:00"],"hovertemplate":"Type=j9<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j9","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j9","offsetgroup":"j9","orientation":"h","showlegend":true,"text":["42-SPTSSU","5-SPTSSU","22-SPTSSU","30-SPTSSU","37-SPTSSU"],"textposition":"auto","x":[36000000.0,28800000.0,50400000.0,43200000.0,43200000.0],"xaxis":"x","y":["M6","M5","M2","M2","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T12:00:00","1970-01-03T01:00:00","1970-01-01T09:00:00"],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j6","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["23-SPTSSU","31-SPTSSU","4-SPTSSU"],"textposition":"auto","x":[46800000.0,39600000.0,32400000.0],"xaxis":"x","y":["M6","M6","M4"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-04T10:00:00","1970-01-05T01:00:00","1970-01-05T13:00:00","1970-01-06T02:00:00","1970-01-06T09:00:00"],"hovertemplate":"Type=j5<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j5","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j5","offsetgroup":"j5","orientation":"h","showlegend":true,"text":["46-SPTSSU","52-SPTSSU","59-SPTSSU","65-SPTSSU","68-SPTSSU"],"textposition":"auto","x":[54000000.0,43200000.0,46800000.0,25200000.0,43200000.0],"xaxis":"x","y":["M6","M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T20:00:00","1970-01-02T02:00:00"],"hovertemplate":"Type=j3<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j3","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"j3","offsetgroup":"j3","orientation":"h","showlegend":true,"text":["6-SPTSSU","10-SPTSSU","14-SPTSSU","19-SPTSSU"],"textposition":"auto","x":[18000000.0,21600000.0,21600000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-06T21:00:00","1970-01-07T17:00:00","1970-01-08T03:00:00","1970-01-08T21:00:00","1970-01-09T08:00:00","1970-01-09T22:00:00"],"hovertemplate":"Type=j20<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j20","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"j20","offsetgroup":"j20","orientation":"h","showlegend":true,"text":["73-SPTSSU","83-SPTSSU","86-SPTSSU","93-SPTSSU","94-SPTSSU","97-SPTSSU"],"textposition":"auto","x":[72000000.0,36000000.0,64800000.0,39600000.0,50400000.0,36000000.0],"xaxis":"x","y":["M6","M6","M6","M5","M3","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-03T12:00:00","1970-01-04T02:00:00","1970-01-05T18:00:00"],"hovertemplate":"Type=j15<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j15","marker":{"color":"#222A2A","pattern":{"shape":""}},"name":"j15","offsetgroup":"j15","orientation":"h","showlegend":true,"text":["38-SPTSSU","44-SPTSSU","61-SPTSSU"],"textposition":"auto","x":[43200000.0,39600000.0,64800000.0],"xaxis":"x","y":["M6","M3","M1"],"yax ...
# <div>                            <div id="fdbd4621-90ae-4fe8-9593-b12e39e7c4ef" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdbd4621-90ae-4fe8-9593-b12e39e7c4ef")) {                    Plotly.newPlot(                        "fdbd4621-90ae-4fe8-9593-b12e39e7c4ef",                        [{"alignmentgroup":"True","base":["1970-01-04T00:00:00","1970-01-02T12:00:00","1970-01-03T01:00:00","1970-01-04T10:00:00","1970-01-05T01:00:00","1970-01-05T13:00:00","1970-01-06T02:00:00","1970-01-06T09:00:00","1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T20:00:00","1970-01-02T02:00:00","1970-01-06T21:00:00","1970-01-07T17:00:00","1970-01-08T03:00:00","1970-01-03T12:00:00","1970-01-01T09:00:00","1970-01-01T17:00:00","1970-01-02T15:00:00","1970-01-03T03:00:00","1970-01-03T08:00:00","1970-01-03T13:00:00","1970-01-04T07:00:00","1970-01-05T00:00:00","1970-01-02T02:00:00","1970-01-08T21:00:00","1970-01-05T10:00:00","1970-01-06T02:00:00","1970-01-06T14:00:00","1970-01-07T05:00:00","1970-01-07T10:00:00","1970-01-08T00:00:00","1970-01-01T09:00:00","1970-01-03T09:00:00","1970-01-04T02:00:00","1970-01-04T15:00:00","1970-01-05T08:00:00","1970-01-06T09:00:00","1970-01-07T03:00:00","1970-01-07T16:00:00","1970-01-08T12:00:00","1970-01-05T19:00:00","1970-01-01T18:00:00","1970-01-02T08:00:00","1970-01-02T14:00:00","1970-01-02T22:00:00","1970-01-01T09:00:00","1970-01-02T20:00:00","1970-01-03T11:00:00","1970-01-09T08:00:00","1970-01-09T22:00:00","1970-01-04T13:00:00","1970-01-05T03:00:00","1970-01-04T02:00:00","1970-01-01T14:00:00","1970-01-05T16:00:00","1970-01-06T12:00:00","1970-01-07T07:00:00","1970-01-07T16:00:00","1970-01-08T10:00:00","1970-01-08T19:00:00","1970-01-02T01:00:00","1970-01-02T13:00:00","1970-01-02T10:00:00","1970-01-03T00:00:00","1970-01-03T12:00:00","1970-01-01T09:00:00","1970-01-01T14:00:00","1970-01-01T19:00:00","1970-01-04T00:00:00","1970-01-08T07:00:00","1970-01-09T09:00:00","1970-01-10T03:00:00","1970-01-06T10:00:00","1970-01-07T01:00:00","1970-01-07T12:00:00","1970-01-02T00:00:00","1970-01-04T13:00:00","1970-01-05T03:00:00","1970-01-05T09:00:00","1970-01-05T23:00:00","1970-01-06T03:00:00","1970-01-01T23:00:00","1970-01-02T08:00:00","1970-01-02T20:00:00","1970-01-10T22:00:00","1970-01-12T01:00:00","1970-01-01T14:00:00","1970-01-06T12:00:00","1970-01-07T02:00:00","1970-01-07T18:00:00","1970-01-08T08:00:00","1970-01-05T18:00:00","1970-01-03T22:00:00","1970-01-04T14:00:00","1970-01-05T01:00:00","1970-01-08T16:00:00","1970-01-09T21:00:00","1970-01-01T09:00:00","1970-01-03T07:00:00"],"hovertemplate":"Rule=%{y}<br>Start=%{base}<br>Finish=%{x}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"SPTSSU","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"SPTSSU","offsetgroup":"SPTSSU","orientation":"h","showlegend":true,"text":["42-SPTSSU","23-SPTSSU","31-SPTSSU","46-SPTSSU","52-SPTSSU","59-SPTSSU","65-SPTSSU","68-SPTSSU","6-SPTSSU","10-SPTSSU","14-SPTSSU","19-SPTSSU","73-SPTSSU","83-SPTSSU","86-SPTSSU","38-SPTSSU","5-SPTSSU","11-SPTSSU","26-SPTSSU","32-SPTSSU","34-SPTSSU","39-SPTSSU","45-SPTSSU","51-SPTSSU","18-SPTSSU","93-SPTSSU","58-SPTSSU","64-SPTSSU","72-SPTSSU","77-SPTSSU","79-SPTSSU","85-SPTSSU","4-SPTSSU","35-SPTSSU","43-SPTSSU","50-SPTSSU","56-SPTSSU","67-SPTSSU","76-SPTSSU","81-SPTSSU","90-SPTSSU","62-SPTSSU","12-SPTSSU","20-SPTSSU","25-SPTSSU","29-SPTSSU","3-SPTSSU","28-SPTSSU","36-SPTSSU","94-SPTSSU","97-SPTSSU","48-SPTSSU","55-SPTSSU","44-SPTSSU","9-SPTSSU","60-SPTSSU","70-SPTSSU","78-SPTSSU","82-SPTSSU","89-SPTSSU","92-SPTSSU","17-SPTSSU","24-SPTSSU","22-SPTSSU","30-SPTSSU","37-SPTSSU","2-SPTSSU","8-SPTSSU","13-SPTSSU","41-SPTSSU","87-SPTSSU","95-SPTSSU","98-SPTSSU","69-SPTSSU","74-SPTSSU","80-SPTSSU","16-SPTSSU","47-SPTSSU","54-SPTSSU","57-SPTSSU","63-SPTSSU","66-SPTSSU","1 ...
# FlowTime: 4962
# machine_util: 0
# util: 0.847636815920398
# makespan: 281
# 0
# <div>                            <div id="593bba42-68a2-4ba1-a584-2f696626fc6a" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("593bba42-68a2-4ba1-a584-2f696626fc6a")) {                    Plotly.newPlot(                        "593bba42-68a2-4ba1-a584-2f696626fc6a",                        [{"alignmentgroup":"True","base":["1970-01-08T05:00:00","1970-01-02T08:00:00","1970-01-03T22:00:00","1970-01-06T01:00:00","1970-01-01T09:00:00","1970-01-01T19:00:00","1970-01-10T13:00:00"],"customdata":[["MOR"],["MOR"],["MOR"],["MOR"],["MOR"],["MOR"],["MOR"]],"hovertemplate":"Type=j7<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j7","marker":{"color":"#2E91E5","pattern":{"shape":""},"line":{"color":"black"}},"name":"j7","offsetgroup":"j7","orientation":"h","showlegend":true,"text":["j0706","j0703","j0704","j0705","j0701","j0702","j0707"],"textposition":"auto","x":[43200000.0,28800000.0,28800000.0,68400000.0,36000000.0,21600000.0,61200000.0],"xaxis":"x","y":["M6","M5","M5","M5","M3","M3","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-10T11:00:00","1970-01-05T23:00:00","1970-01-08T05:00:00"],"customdata":[["MOR"],["MOR"],["MOR"]],"hovertemplate":"Type=j6<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j6","marker":{"color":"#E15F99","pattern":{"shape":""},"line":{"color":"black"}},"name":"j6","offsetgroup":"j6","orientation":"h","showlegend":true,"text":["j0603","j0601","j0602"],"textposition":"auto","x":[50400000.0,54000000.0,72000000.0],"xaxis":"x","y":["M6","M3","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T02:00:00","1970-01-03T20:00:00","1970-01-05T22:00:00","1970-01-08T03:00:00","1970-01-10T09:00:00"],"customdata":[["MOR"],["MOR"],["MOR"],["MOR"],["MOR"]],"hovertemplate":"Type=j5<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j5","marker":{"color":"#1CA71C","pattern":{"shape":""},"line":{"color":"black"}},"name":"j5","offsetgroup":"j5","orientation":"h","showlegend":true,"text":["j0501","j0502","j0503","j0504","j0505"],"textposition":"auto","x":[61200000.0,54000000.0,61200000.0,43200000.0,50400000.0],"xaxis":"x","y":["M6","M6","M6","M5","M4"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-05T01:00:00","1970-01-09T20:00:00","1970-01-12T02:00:00","1970-01-07T17:00:00","1970-01-03T10:00:00"],"customdata":[["MOR"],["MOR"],["MOR"],["MOR"],["MOR"],["MOR"]],"hovertemplate":"Type=j20<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j20","marker":{"color":"#FB0D0D","pattern":{"shape":""},"line":{"color":"black"}},"name":"j20","offsetgroup":"j20","orientation":"h","showlegend":true,"text":["j2001","j2003","j2005","j2006","j2004","j2002"],"textposition":"auto","x":[61200000.0,75600000.0,54000000.0,39600000.0,32400000.0,54000000.0],"xaxis":"x","y":["M6","M6","M6","M6","M2","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T19:00:00","1970-01-07T08:00:00","1970-01-09T10:00:00","1970-01-11T16:00:00","1970-01-04T23:00:00"],"customdata":[["MOR"],["MOR"],["MOR"],["MOR"],["MOR"]],"hovertemplate":"Type=j18<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Task=%{text}<br>Rule=%{customdata[0]}<extra></extra>","legendgroup":"j18","marker":{"color":"#DA16FF","pattern":{"shape":""},"line":{"color":"black"}},"name":"j18","offsetgroup":"j18","orientation":"h","showlegend":true,"text":["j1801","j1803","j1804","j1805","j1802"],"textposition":"auto","x":[90000000.0,68400000.0,50400000.0,57600000.0,32400000.0],"xax ...
# ...
# <div>                            <div id="e12f8e12-d4ca-4388-860a-f736c529710b" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e12f8e12-d4ca-4388-860a-f736c529710b")) {                    Plotly.newPlot(                        "e12f8e12-d4ca-4388-860a-f736c529710b",                        [{"alignmentgroup":"True","base":["1970-01-03T07:00:00","1970-01-07T18:00:00","1970-01-08T10:00:00","1970-01-09T02:00:00","1970-01-09T22:00:00"],"hovertemplate":"Type=j4<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j4","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j4","offsetgroup":"j4","orientation":"h","showlegend":true,"text":["LPT","LPT","LPT","LPT","LPT"],"textposition":"auto","x":[64800000.0,57600000.0,50400000.0,72000000.0,90000000.0],"xaxis":"x","y":["M6","M6","M6","M3","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-06T03:00:00","1970-01-06T22:00:00","1970-01-03T09:00:00","1970-01-03T23:00:00"],"hovertemplate":"Type=j18<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j18","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j18","offsetgroup":"j18","orientation":"h","showlegend":true,"text":["LPT","LPT","LPT","LPT","LPT"],"textposition":"auto","x":[79200000.0,68400000.0,72000000.0,50400000.0,75600000.0],"xaxis":"x","y":["M6","M6","M6","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-10T12:00:00","1970-01-11T01:00:00","1970-01-11T18:00:00","1970-01-12T04:00:00","1970-01-03T05:00:00","1970-01-12T22:00:00","1970-01-13T20:00:00","1970-01-14T12:00:00"],"hovertemplate":"Type=j16<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j16","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j16","offsetgroup":"j16","orientation":"h","showlegend":true,"text":["LPT","LPT","LPT","LPT","LPT","LPT","LPT","LPT"],"textposition":"auto","x":[46800000.0,61200000.0,36000000.0,64800000.0,64800000.0,79200000.0,57600000.0,18000000.0],"xaxis":"x","y":["M6","M6","M6","M6","M5","M4","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-09T00:00:00","1970-01-09T14:00:00","1970-01-02T07:00:00"],"hovertemplate":"Type=j15<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j15","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"j15","offsetgroup":"j15","orientation":"h","showlegend":true,"text":["LPT","LPT","LPT"],"textposition":"auto","x":[50400000.0,79200000.0,75600000.0],"xaxis":"x","y":["M6","M6","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-04T01:00:00","1970-01-04T17:00:00","1970-01-05T08:00:00","1970-01-01T09:00:00"],"hovertemplate":"Type=j14<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j14","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"j14","offsetgroup":"j14","orientation":"h","showlegend":true,"text":["LPT","LPT","LPT","LPT"],"textposition":"auto","x":[57600000.0,54000000.0,68400000.0,86400000.0],"xaxis":"x","y":["M6","M6","M6","M4"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T07:00:00","1970-01-11T21:00:00","1970-01-12T06:00:00","1970-01-05T00:00:00","1970-01-06T19:00:00"],"hovertemplate":"Type=j12<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Rule=%{text}<extra></extra>","legendgroup":"j12","marker":{"color":"#222A2A","pattern":{"shape":""}},"name":"j12","offsetgroup":"j12","orientation":"h","showlegend":true,"text":["LPT","LPT","LPT","LPT","LPT"],"textposition":"auto","x":[86400000.0,32400000.0,32400000.0,82800000.0,64800000.0],"xaxis":"x","y":["M6","M5","M5","M4","M2"] ...
# <div>                            <div id="ce391652-09e3-4410-b631-dd5a23b7701b" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce391652-09e3-4410-b631-dd5a23b7701b")) {                    Plotly.newPlot(                        "ce391652-09e3-4410-b631-dd5a23b7701b",                        [{"alignmentgroup":"True","base":["1970-01-03T07:00:00","1970-01-07T18:00:00","1970-01-08T10:00:00","1970-01-09T02:00:00","1970-01-09T22:00:00"],"hovertemplate":"Type=j4<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j4","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"j4","offsetgroup":"j4","orientation":"h","showlegend":true,"text":["16-LPT","50-LPT","55-LPT","61-LPT","69-LPT"],"textposition":"auto","x":[64800000.0,57600000.0,50400000.0,72000000.0,90000000.0],"xaxis":"x","y":["M6","M6","M6","M3","M3"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-01T09:00:00","1970-01-06T03:00:00","1970-01-06T22:00:00","1970-01-03T09:00:00","1970-01-03T23:00:00"],"hovertemplate":"Type=j18<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j18","marker":{"color":"#E15F99","pattern":{"shape":""}},"name":"j18","offsetgroup":"j18","orientation":"h","showlegend":true,"text":["6-LPT","37-LPT","44-LPT","18-LPT","20-LPT"],"textposition":"auto","x":[79200000.0,68400000.0,72000000.0,50400000.0,75600000.0],"xaxis":"x","y":["M6","M6","M6","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-10T12:00:00","1970-01-11T01:00:00","1970-01-11T18:00:00","1970-01-12T04:00:00","1970-01-03T05:00:00","1970-01-12T22:00:00","1970-01-13T20:00:00","1970-01-14T12:00:00"],"hovertemplate":"Type=j16<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j16","marker":{"color":"#1CA71C","pattern":{"shape":""}},"name":"j16","offsetgroup":"j16","orientation":"h","showlegend":true,"text":["74-LPT","80-LPT","86-LPT","91-LPT","14-LPT","97-LPT","99-LPT","100-LPT"],"textposition":"auto","x":[46800000.0,61200000.0,36000000.0,64800000.0,64800000.0,79200000.0,57600000.0,18000000.0],"xaxis":"x","y":["M6","M6","M6","M6","M5","M4","M1","M1"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-09T00:00:00","1970-01-09T14:00:00","1970-01-02T07:00:00"],"hovertemplate":"Type=j15<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j15","marker":{"color":"#FB0D0D","pattern":{"shape":""}},"name":"j15","offsetgroup":"j15","orientation":"h","showlegend":true,"text":["60-LPT","65-LPT","7-LPT"],"textposition":"auto","x":[50400000.0,79200000.0,75600000.0],"xaxis":"x","y":["M6","M6","M2"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-04T01:00:00","1970-01-04T17:00:00","1970-01-05T08:00:00","1970-01-01T09:00:00"],"hovertemplate":"Type=j14<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j14","marker":{"color":"#DA16FF","pattern":{"shape":""}},"name":"j14","offsetgroup":"j14","orientation":"h","showlegend":true,"text":["21-LPT","26-LPT","31-LPT","4-LPT"],"textposition":"auto","x":[57600000.0,54000000.0,68400000.0,86400000.0],"xaxis":"x","y":["M6","M6","M6","M4"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","base":["1970-01-02T07:00:00","1970-01-11T21:00:00","1970-01-12T06:00:00","1970-01-05T00:00:00","1970-01-06T19:00:00"],"hovertemplate":"Type=j12<br>Start=%{base}<br>Finish=%{x}<br>Resource=%{y}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"j12","marker":{"color":"#222A2A","pattern":{"shape":""}},"name":"j12","offsetgroup":"j12","orientation":"h","showlegend":true,"text":["8-LPT","87-LPT","92-LPT","30-LPT","41-LPT"],"textpos ...
# <div>                            <div id="345def41-b341-4b97-b680-429adcb6ce25" class="plotly-graph-div" style="height:800px; width:2000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("345def41-b341-4b97-b680-429adcb6ce25")) {                    Plotly.newPlot(                        "345def41-b341-4b97-b680-429adcb6ce25",                        [{"alignmentgroup":"True","base":["1970-01-03T07:00:00","1970-01-07T18:00:00","1970-01-08T10:00:00","1970-01-01T09:00:00","1970-01-06T03:00:00","1970-01-06T22:00:00","1970-01-10T12:00:00","1970-01-11T01:00:00","1970-01-11T18:00:00","1970-01-12T04:00:00","1970-01-09T00:00:00","1970-01-09T14:00:00","1970-01-04T01:00:00","1970-01-04T17:00:00","1970-01-05T08:00:00","1970-01-02T07:00:00","1970-01-06T20:00:00","1970-01-03T23:00:00","1970-01-04T14:00:00","1970-01-02T08:00:00","1970-01-05T11:00:00","1970-01-06T05:00:00","1970-01-10T06:00:00","1970-01-03T05:00:00","1970-01-07T10:00:00","1970-01-08T03:00:00","1970-01-08T17:00:00","1970-01-09T07:00:00","1970-01-11T21:00:00","1970-01-12T06:00:00","1970-01-01T09:00:00","1970-01-10T22:00:00","1970-01-11T09:00:00","1970-01-06T22:00:00","1970-01-07T20:00:00","1970-01-08T10:00:00","1970-01-09T02:00:00","1970-01-09T18:00:00","1970-01-10T07:00:00","1970-01-10T22:00:00","1970-01-02T09:00:00","1970-01-03T06:00:00","1970-01-04T04:00:00","1970-01-12T22:00:00","1970-01-01T09:00:00","1970-01-05T00:00:00","1970-01-11T15:00:00","1970-01-12T02:00:00","1970-01-05T23:00:00","1970-01-04T03:00:00","1970-01-06T08:00:00","1970-01-09T02:00:00","1970-01-09T22:00:00","1970-01-03T07:00:00","1970-01-12T12:00:00","1970-01-12T22:00:00","1970-01-07T00:00:00","1970-01-07T15:00:00","1970-01-08T07:00:00","1970-01-10T23:00:00","1970-01-11T14:00:00","1970-01-01T09:00:00","1970-01-02T09:00:00","1970-01-05T12:00:00","1970-01-04T20:00:00","1970-01-08T16:00:00","1970-01-09T06:00:00","1970-01-09T18:00:00","1970-01-10T09:00:00","1970-01-10T22:00:00","1970-01-11T16:00:00","1970-01-07T13:00:00","1970-01-08T06:00:00","1970-01-05T19:00:00","1970-01-04T23:00:00","1970-01-01T09:00:00","1970-01-03T04:00:00","1970-01-02T07:00:00","1970-01-06T19:00:00","1970-01-04T08:00:00","1970-01-12T04:00:00","1970-01-12T11:00:00","1970-01-12T21:00:00","1970-01-09T16:00:00","1970-01-06T15:00:00","1970-01-01T09:00:00","1970-01-10T06:00:00","1970-01-10T20:00:00","1970-01-11T17:00:00","1970-01-12T03:00:00","1970-01-12T14:00:00","1970-01-07T10:00:00","1970-01-08T13:00:00","1970-01-03T09:00:00","1970-01-03T23:00:00","1970-01-04T20:00:00","1970-01-05T20:00:00","1970-01-13T20:00:00","1970-01-14T12:00:00","1970-01-02T10:00:00"],"hovertemplate":"Rule=%{y}<br>Start=%{base}<br>Finish=%{x}<br>Step-Rule=%{text}<extra></extra>","legendgroup":"LPT","marker":{"color":"#2E91E5","pattern":{"shape":""}},"name":"LPT","offsetgroup":"LPT","orientation":"h","showlegend":true,"text":["16-LPT","50-LPT","55-LPT","6-LPT","37-LPT","44-LPT","74-LPT","80-LPT","86-LPT","91-LPT","60-LPT","65-LPT","21-LPT","26-LPT","31-LPT","8-LPT","42-LPT","19-LPT","25-LPT","9-LPT","32-LPT","38-LPT","70-LPT","14-LPT","47-LPT","52-LPT","59-LPT","64-LPT","87-LPT","92-LPT","5-LPT","76-LPT","81-LPT","43-LPT","51-LPT","56-LPT","62-LPT","67-LPT","72-LPT","77-LPT","11-LPT","15-LPT","23-LPT","97-LPT","4-LPT","30-LPT","83-LPT","88-LPT","36-LPT","22-LPT","39-LPT","61-LPT","69-LPT","17-LPT","94-LPT","98-LPT","45-LPT","49-LPT","54-LPT","79-LPT","82-LPT","3-LPT","10-LPT","33-LPT","28-LPT","58-LPT","63-LPT","68-LPT","73-LPT","78-LPT","84-LPT","48-LPT","53-LPT","34-LPT","29-LPT","2-LPT","13-LPT","7-LPT","41-LPT","24-LPT","90-LPT","93-LPT","96-LPT","66-LPT","40-LPT","1-LPT","71-LPT","75-LPT","85-LPT","89-LPT","95-LPT","46-LPT","57-LPT","18-LPT","20-LPT","27-LPT","35-LPT","99-LPT","100-LPT","12-LPT"],"textposition":"auto","x":[64800000.0,57600000.0,50400000.0,79200000.0,68400000.0,72000000.0,46 ...
# 217
# 2576
# 0.9665697674418605
# 1.637
# 20.843
# 0.005361397759606972
